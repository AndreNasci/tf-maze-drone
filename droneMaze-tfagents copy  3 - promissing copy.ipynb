# %% [markdown]
# # MazeDrone with TF Agents

# %% [markdown]
# ### Setup

# %%
import os
# Keep using keras-2 (tf-keras) rather than keras-3 (keras).
os.environ['TF_USE_LEGACY_KERAS'] = '1'

from __future__ import absolute_import, division, print_function

import base64
import imageio
import IPython

import matplotlib.pyplot as plt
import numpy as np
import PIL.Image

import tensorflow as tf
from tf_agents.agents.dqn import dqn_agent
from tf_agents.environments import suite_gym
from tf_agents.environments import tf_py_environment
from tf_agents.metrics import tf_metrics
from tf_agents.networks import sequential
from tf_agents.policies import random_tf_policy
from tf_agents.specs import tensor_spec
from tf_agents.utils import common

import sys
import gym
import gym_maze

# %% [markdown]
# ### Hyperparameters

# %%
num_iterations = 500_000 # @param {type:"integer"}

initial_collect_steps = 100  # @param {type:"integer"}
collect_steps_per_iteration = 1 # @param {type:"integer"}
#replay_buffer_max_length = 100000  # @param {type:"integer"}
replay_buffer_max_length = 100  # @param {type:"integer"}

batch_size = 64  # @param {type:"integer"}
learning_rate = 1e-3  # @param {type:"number"}
log_interval = 200  # @param {type:"integer"}

num_eval_episodes = 10  # @param {type:"integer"}
eval_interval = 1000  # @param {type:"integer"}

# %% [markdown]
# ### Environment

# %%
# Some necessary imports 
#sys.path.append('/home/naski/Documents/dev/maze_drone_v02/maze-drone-v02/lib/python3.10/site-packages')

# %%
# Importing custom environment
env_name = 'maze-v0'
env = suite_gym.load(env_name)

# Testing
env.reset()
# Out:
# TimeStep(
# {'step_type': array(0, dtype=int32),
#  'reward': array(0., dtype=float32),
#  'discount': array(1., dtype=float32),
#  'observation': array([0., 1., 0., 0., 1.], dtype=float32)})

# %% [markdown]
# Usually two environments are instantiated: one for training and one for evaluation.

# %%
train_py_env = suite_gym.load(env_name)
eval_py_env = suite_gym.load(env_name)

# Converts environments, originally in pure Python, to tensors (using a wrapper)
train_env = tf_py_environment.TFPyEnvironment(train_py_env)
eval_env = tf_py_environment.TFPyEnvironment(eval_py_env)

# %% [markdown]
# ### Agent

# %%
fc_layer_params = (200, 100, 50, ) # fc = fully connected
#fc_layer_params = (100, 10, 10, )

action_tensor_spec = tensor_spec.from_spec(env.action_spec())
num_actions = action_tensor_spec.maximum - action_tensor_spec.minimum + 1

# Define a helper function to create Dense layers configured with the right
# activation and kernel initializer.
def dense_layer(num_units):
  return tf.keras.layers.Dense(
      num_units,
      activation=tf.keras.activations.relu,
      kernel_initializer=tf.keras.initializers.VarianceScaling(
          scale=2.0, mode='fan_in', distribution='truncated_normal'))
# O uso do inicializador VarianceScaling com mode='fan_in' e 
# distribution='truncated_normal' no seu código é uma estratégia para manter
# a variância dos sinais aproximadamente constante nas camadas densas da rede.
# Crucial para garantir um treinamento eficiente e evitar problemas como o 
# vanishing gradient (gradiente evanescente) e o exploding gradient 
# (gradiente explosivo).

# QNetwork consists of a sequence of Dense layers followed by a dense layer
# with `num_actions` units to generate one q_value per available action as
# its output.
dense_layers = [dense_layer(num_units) for num_units in fc_layer_params]
q_values_layer = tf.keras.layers.Dense(
    num_actions,
    activation=None,
    kernel_initializer=tf.keras.initializers.RandomUniform(
        minval=-0.03, maxval=0.03),
    bias_initializer=tf.keras.initializers.Constant(-0.2))
q_net = sequential.Sequential(dense_layers + [q_values_layer])

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)

train_step_counter = tf.Variable(0)

agent = dqn_agent.DqnAgent(
    train_env.time_step_spec(),
    train_env.action_spec(),
    q_network=q_net,
    optimizer=optimizer,
    td_errors_loss_fn=common.element_wise_squared_loss,
    train_step_counter=train_step_counter)

agent.initialize()

# %% [markdown]
# ### Policies

# %%
# The main policy that is used for evaluation and deployment.
eval_policy = agent.policy
# A second policy that is used for data collection.
collect_policy = agent.collect_policy

# %% [markdown]
# ### Metrics and Evaluation

# %%
def compute_avg_return(environment, policy, num_episodes=10):

  total_return = 0.0
  for _ in range(num_episodes):

    time_step = environment.reset()
    episode_return = 0.0

    while not time_step.is_last():
      action_step = policy.action(time_step)
      time_step = environment.step(action_step.action)
      episode_return += time_step.reward
    total_return += episode_return

  avg_return = total_return / num_episodes
  return avg_return.numpy()[0]


# See also the metrics module for standard implementations of different metrics.
# https://github.com/tensorflow/agents/tree/master/tf_agents/metrics

# %% [markdown]
# ### New Observer

# %%
from tf_agents.metrics import py_metric

class MyMetric(py_metric.PyMetric):

    def __init__(self, name="MyMetric"):
        super(MyMetric, self).__init__(name=name)
        self._count = 0

    def call(self, trajectory):
        if trajectory.reward.numpy()[0] == -51.:
            self._count += 1

    def result(self):
        return self._count
    
    def reset(self):
        self._count = 0

# Create an instance of MyMetric
my_metric = MyMetric()

# %% [markdown]
# ### Replay Buffer

# %%
from tf_agents.drivers import dynamic_step_driver
from tf_agents.replay_buffers import tf_uniform_replay_buffer

# %%
replay_buffer_capacity = replay_buffer_max_length

replay_buffer = tf_uniform_replay_buffer.TFUniformReplayBuffer(
    agent.collect_data_spec,
    batch_size=train_env.batch_size,
    max_length=replay_buffer_capacity)

num_episodes = tf_metrics.NumberOfEpisodes()
env_steps = tf_metrics.EnvironmentSteps()

# Add an observer that adds to the replay buffer:
replay_observer = [replay_buffer.add_batch, num_episodes, env_steps, my_metric]

# %% [markdown]
# ### Data Collection

# %%
# Data collection:
collect_op = dynamic_step_driver.DynamicStepDriver(
  train_env,
  agent.collect_policy,
  observers=replay_observer,
  num_steps=collect_steps_per_iteration).run()

# %%
# Dataset generates trajectories with shape [Bx2x...]
dataset = replay_buffer.as_dataset(
    num_parallel_calls=3,
    sample_batch_size=batch_size,
    num_steps=2).prefetch(3)
# Out:
# WARNING:tensorflow:From /home/naski/Documents/dev/maze_drone_v02/maze-drone-v03/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py:377: ReplayBuffer.get_next (from tf_agents.replay_buffers.replay_buffer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `as_dataset(..., single_deterministic_pass=False) instead.

# %% [markdown]
# ### Training the Agent

# %%
# %%time

# (Optional) Optimize by wrapping some of the code in a graph using TF function.
agent.train = common.function(agent.train)

# Reset the train step.
agent.train_step_counter.assign(0)

# Evaluate the agent's policy once before training.
avg_return = compute_avg_return(eval_env, agent.policy, num_eval_episodes)
returns = [avg_return]

# Reset the environment.
time_step = train_py_env.reset()

# Create a driver to collect experience.
collect_driver = dynamic_step_driver.DynamicStepDriver(
    train_env,
    agent.collect_policy,
    observers=replay_observer,
    num_steps=collect_steps_per_iteration)

iterator = iter(dataset)

loss_log = []
step_log = []
steps_per_episode_log = []
episodes_per_log_interval = []
previous_n_episodes = 0

my_metric_log = []

avg_steps_per_episode_per_eval_interval = []

for _ in range(num_iterations):

    # Collect a few steps and save to the replay buffer.
    time_step, _ = collect_driver.run()

    # Sample a batch of data from the buffer and update the agent's network.
    trajectories, _ = next(iterator)
    train_loss = agent.train(experience=trajectories).loss

    step = agent.train_step_counter.numpy()

    if step % log_interval == 0:
        #print('step = {0}: loss = {1}'.format(step, train_loss))
        step_log.append(step)
        loss_log.append(train_loss)
        episodes_per_log_interval.append(num_episodes.result().numpy() - previous_n_episodes)
        steps_per_episode_log.append(log_interval / (episodes_per_log_interval[-1]))
        previous_n_episodes = num_episodes.result().numpy()

    if step % eval_interval == 0:
        print('step = {0}: loss = {1}'.format(step, train_loss))
        avg_return = compute_avg_return(eval_env, agent.policy, num_eval_episodes)
        print('step = {0}: Average Return = {1}'.format(step, avg_return))
        returns.append(avg_return)
        avg_steps_per_episode_per_eval_interval.append(eval_interval / sum(episodes_per_log_interval[-10:]))
        print('Avg of Steps/Episode: {:.2f}'.format(avg_steps_per_episode_per_eval_interval[-1]) )

        current_value = my_metric.result()
        my_metric_log.append(current_value)
# Out:
# WARNING:tensorflow:From /home/naski/Documents/dev/maze_drone_v02/maze-drone-v03/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py:1260: calling foldr_v2 (from tensorflow.python.ops.functional_ops) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.foldr(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.foldr(fn, elems))
# step = 1000: loss = 9710.5986328125
# step = 1000: Average Return = -2535.0
# Avg of Steps/Episode: 35.71
# step = 2000: loss = 1559.4481201171875
# step = 2000: Average Return = -1945.199951171875
# Avg of Steps/Episode: 19.23
# step = 3000: loss = 2613.695068359375
# step = 3000: Average Return = -2195.0
# Avg of Steps/Episode: 19.23
# step = 4000: loss = 6460.7392578125
# step = 4000: Average Return = -1326.199951171875
# Avg of Steps/Episode: 17.86
# step = 5000: loss = 13938.54296875
# step = 5000: Average Return = -2220.60009765625
# Avg of Steps/Episode: 16.95
# step = 6000: loss = 6314.68212890625
# step = 6000: Average Return = -1866.699951171875
# Avg of Steps/Episode: 16.13
# step = 7000: loss = 2965.046142578125
# step = 7000: Average Return = -1311.5999755859375
# Avg of Steps/Episode: 15.15
# step = 8000: loss = 7751.9951171875
# step = 8000: Average Return = -2165.39990234375
# Avg of Steps/Episode: 14.71
# step = 9000: loss = 24021.98046875
# step = 9000: Average Return = -2088.0
# Avg of Steps/Episode: 17.54
# step = 10000: loss = 5618.77294921875
# step = 10000: Average Return = -1287.0999755859375
# Avg of Steps/Episode: 17.24
# step = 11000: loss = 1482.087158203125
# step = 11000: Average Return = -2386.60009765625
# Avg of Steps/Episode: 14.49
# step = 12000: loss = 5749.14208984375
# step = 12000: Average Return = -2215.0
# Avg of Steps/Episode: 16.39
# step = 13000: loss = 4704.60107421875
# step = 13000: Average Return = -1910.4000244140625
# Avg of Steps/Episode: 18.18
# step = 14000: loss = 9912.146484375
# step = 14000: Average Return = -1537.699951171875
# Avg of Steps/Episode: 16.39
# step = 15000: loss = 24187.84375
# step = 15000: Average Return = -1046.5999755859375
# Avg of Steps/Episode: 16.67
# step = 16000: loss = 5462.76806640625
# step = 16000: Average Return = -2171.199951171875
# Avg of Steps/Episode: 17.24
# step = 17000: loss = 17597.365234375
# step = 17000: Average Return = -2117.89990234375
# Avg of Steps/Episode: 16.39
# step = 18000: loss = 8439.20703125
# step = 18000: Average Return = -1542.699951171875
# Avg of Steps/Episode: 17.24
# step = 19000: loss = 9468.78515625
# step = 19000: Average Return = -1307.0999755859375
# Avg of Steps/Episode: 17.24
# step = 20000: loss = 11291.021484375
# step = 20000: Average Return = -1287.0
# Avg of Steps/Episode: 15.87
# step = 21000: loss = 8451.0078125
# step = 21000: Average Return = -1817.9000244140625
# Avg of Steps/Episode: 15.62
# step = 22000: loss = 2870.078369140625
# step = 22000: Average Return = -1857.300048828125
# Avg of Steps/Episode: 16.95
# step = 23000: loss = 7483.46826171875
# step = 23000: Average Return = -2215.0
# Avg of Steps/Episode: 20.41
# step = 24000: loss = 3483.03759765625
# step = 24000: Average Return = -2387.5
# Avg of Steps/Episode: 21.74
# step = 25000: loss = 40062.45703125
# step = 25000: Average Return = -1885.699951171875
# Avg of Steps/Episode: 19.23
# step = 26000: loss = 4173.736328125
# step = 26000: Average Return = -1547.4000244140625
# Avg of Steps/Episode: 17.86
# step = 27000: loss = 9156.0673828125
# step = 27000: Average Return = -1793.4000244140625
# Avg of Steps/Episode: 16.95
# step = 28000: loss = 1639.4453125
# step = 28000: Average Return = -1871.5
# Avg of Steps/Episode: 17.54
# step = 29000: loss = 1762.3155517578125
# step = 29000: Average Return = -1837.300048828125
# Avg of Steps/Episode: 17.86
# step = 30000: loss = 3335.765380859375
# step = 30000: Average Return = -1542.800048828125
# Avg of Steps/Episode: 16.13
# step = 31000: loss = 13716.349609375
# step = 31000: Average Return = -1601.699951171875
# Avg of Steps/Episode: 17.24
# step = 32000: loss = 13031.3193359375
# step = 32000: Average Return = -1630.4000244140625
# Avg of Steps/Episode: 19.23
# step = 33000: loss = 1558.169677734375
# step = 33000: Average Return = -1601.800048828125
# Avg of Steps/Episode: 16.67
# step = 34000: loss = 6067.0732421875
# step = 34000: Average Return = -2328.39990234375
# Avg of Steps/Episode: 15.38
# step = 35000: loss = 9620.1611328125
# step = 35000: Average Return = -1611.199951171875
# Avg of Steps/Episode: 16.39
# step = 36000: loss = 9042.46484375
# step = 36000: Average Return = -1645.0999755859375
# Avg of Steps/Episode: 15.87
# step = 37000: loss = 14145.8955078125
# step = 37000: Average Return = -2146.800048828125
# Avg of Steps/Episode: 14.93
# step = 38000: loss = 5864.625
# step = 38000: Average Return = -1365.5
# Avg of Steps/Episode: 15.87
# step = 39000: loss = 7192.509765625
# step = 39000: Average Return = -2102.699951171875
# Avg of Steps/Episode: 15.87
# step = 40000: loss = 15966.234375
# step = 40000: Average Return = -2348.10009765625
# Avg of Steps/Episode: 13.89
# step = 41000: loss = 2725.514404296875
# step = 41000: Average Return = -2043.5999755859375
# Avg of Steps/Episode: 16.39
# step = 42000: loss = 3581.40771484375
# step = 42000: Average Return = -2475.60009765625
# Avg of Steps/Episode: 19.23
# step = 43000: loss = 11384.3896484375
# step = 43000: Average Return = -2392.39990234375
# Avg of Steps/Episode: 16.39
# step = 44000: loss = 4968.93994140625
# step = 44000: Average Return = -1817.9000244140625
# Avg of Steps/Episode: 15.15
# step = 45000: loss = 2719.28759765625
# step = 45000: Average Return = -1041.5
# Avg of Steps/Episode: 14.93
# step = 46000: loss = 5999.2080078125
# step = 46000: Average Return = -825.7000122070312
# Avg of Steps/Episode: 17.24
# step = 47000: loss = 16927.46875
# step = 47000: Average Return = -1975.0999755859375
# Avg of Steps/Episode: 20.41
# step = 48000: loss = 15487.404296875
# step = 48000: Average Return = -1095.5
# Avg of Steps/Episode: 20.41
# step = 49000: loss = 2956.75927734375
# step = 49000: Average Return = -1866.699951171875
# Avg of Steps/Episode: 18.52
# step = 50000: loss = 2644.1767578125
# step = 50000: Average Return = -1615.199951171875
# Avg of Steps/Episode: 16.95
# step = 51000: loss = 24818.8046875
# step = 51000: Average Return = -1017.5
# Avg of Steps/Episode: 16.67
# step = 52000: loss = 6508.14208984375
# step = 52000: Average Return = -1007.7999877929688
# Avg of Steps/Episode: 16.13
# step = 53000: loss = 38436.203125
# step = 53000: Average Return = -1793.0
# Avg of Steps/Episode: 14.93
# step = 54000: loss = 7214.568359375
# step = 54000: Average Return = -2240.0
# Avg of Steps/Episode: 14.08
# step = 55000: loss = 4389.96875
# step = 55000: Average Return = -1547.699951171875
# Avg of Steps/Episode: 15.38
# step = 56000: loss = 15706.0029296875
# step = 56000: Average Return = -1552.300048828125
# Avg of Steps/Episode: 17.86
# step = 57000: loss = 2830.652587890625
# step = 57000: Average Return = -2215.0
# Avg of Steps/Episode: 18.18
# step = 58000: loss = 21253.7734375
# step = 58000: Average Return = -2475.5
# Avg of Steps/Episode: 17.54
# step = 59000: loss = 16537.033203125
# step = 59000: Average Return = -1802.800048828125
# Avg of Steps/Episode: 16.67
# step = 60000: loss = 8368.228515625
# step = 60000: Average Return = -2180.5
# Avg of Steps/Episode: 14.93
# step = 61000: loss = 14008.986328125
# step = 61000: Average Return = -1552.4000244140625
# Avg of Steps/Episode: 15.38
# step = 62000: loss = 3525.178466796875
# step = 62000: Average Return = -1965.199951171875
# Avg of Steps/Episode: 16.95
# step = 63000: loss = 6677.72265625
# step = 63000: Average Return = -1901.4000244140625
# Avg of Steps/Episode: 15.62
# step = 64000: loss = 2556.546142578125
# step = 64000: Average Return = -2131.800048828125
# Avg of Steps/Episode: 17.24
# step = 65000: loss = 5379.89599609375
# step = 65000: Average Return = -2092.699951171875
# Avg of Steps/Episode: 17.86
# step = 66000: loss = 7669.0791015625
# step = 66000: Average Return = -1950.4000244140625
# Avg of Steps/Episode: 15.87
# step = 67000: loss = 7222.46484375
# step = 67000: Average Return = -1822.5
# Avg of Steps/Episode: 17.24
# step = 68000: loss = 13049.375
# step = 68000: Average Return = -1311.5999755859375
# Avg of Steps/Episode: 17.54
# step = 69000: loss = 5510.8994140625
# step = 69000: Average Return = -2097.699951171875
# Avg of Steps/Episode: 15.62
# step = 70000: loss = 12540.2373046875
# step = 70000: Average Return = -1802.800048828125
# Avg of Steps/Episode: 16.13
# step = 71000: loss = 2110.25048828125
# step = 71000: Average Return = -1571.9000244140625
# Avg of Steps/Episode: 16.13
# step = 72000: loss = 29856.134765625
# step = 72000: Average Return = -1547.699951171875
# Avg of Steps/Episode: 16.13
# step = 73000: loss = 3358.570068359375
# step = 73000: Average Return = -1915.5
# Avg of Steps/Episode: 16.39
# step = 74000: loss = 25761.236328125
# step = 74000: Average Return = -1262.800048828125
# Avg of Steps/Episode: 17.54
# step = 75000: loss = 4828.228515625
# step = 75000: Average Return = -1832.4000244140625
# Avg of Steps/Episode: 17.24
# step = 76000: loss = 5313.63330078125
# step = 76000: Average Return = -497.70001220703125
# Avg of Steps/Episode: 17.24
# step = 77000: loss = 6223.81103515625
# step = 77000: Average Return = -1557.5
# Avg of Steps/Episode: 20.83
# step = 78000: loss = 7700.9921875
# step = 78000: Average Return = -2112.300048828125
# Avg of Steps/Episode: 19.23
# step = 79000: loss = 19500.4140625
# step = 79000: Average Return = -1900.9000244140625
# Avg of Steps/Episode: 17.24
# step = 80000: loss = 5491.15771484375
# step = 80000: Average Return = -1807.9000244140625
# Avg of Steps/Episode: 17.54
# step = 81000: loss = 12049.251953125
# step = 81000: Average Return = -1066.5999755859375
# Avg of Steps/Episode: 17.86
# step = 82000: loss = 9090.8046875
# step = 82000: Average Return = -1680.199951171875
# Avg of Steps/Episode: 15.87
# step = 83000: loss = 9316.4052734375
# step = 83000: Average Return = -1906.0999755859375
# Avg of Steps/Episode: 13.33
# step = 84000: loss = 37489.33203125
# step = 84000: Average Return = -2107.60009765625
# Avg of Steps/Episode: 13.89
# step = 85000: loss = 15213.466796875
# step = 85000: Average Return = -2525.0
# Avg of Steps/Episode: 16.95
# step = 86000: loss = 6310.36962890625
# step = 86000: Average Return = -2195.10009765625
# Avg of Steps/Episode: 16.67
# step = 87000: loss = 4327.24609375
# step = 87000: Average Return = -1547.800048828125
# Avg of Steps/Episode: 17.54
# step = 88000: loss = 16331.802734375
# step = 88000: Average Return = -1812.699951171875
# Avg of Steps/Episode: 18.18
# step = 89000: loss = 5718.341796875
# step = 89000: Average Return = -1046.800048828125
# Avg of Steps/Episode: 16.67
# step = 90000: loss = 3022.998779296875
# step = 90000: Average Return = -737.5
# Avg of Steps/Episode: 15.87
# step = 91000: loss = 1651.820068359375
# step = 91000: Average Return = -1935.199951171875
# Avg of Steps/Episode: 16.39
# step = 92000: loss = 11543.431640625
# step = 92000: Average Return = -2145.89990234375
# Avg of Steps/Episode: 17.54
# step = 93000: loss = 2390.130859375
# step = 93000: Average Return = -1596.5
# Avg of Steps/Episode: 16.95
# step = 94000: loss = 2408.71875
# step = 94000: Average Return = -1576.9000244140625
# Avg of Steps/Episode: 17.24
# step = 95000: loss = 8529.2802734375
# step = 95000: Average Return = -2431.800048828125
# Avg of Steps/Episode: 16.13
# step = 96000: loss = 8386.423828125
# step = 96000: Average Return = -2308.89990234375
# Avg of Steps/Episode: 16.13
# step = 97000: loss = 3716.41748046875
# step = 205000: loss = 3400.53662109375
# step = 205000: Average Return = -2451.5
# Avg of Steps/Episode: 16.67
# step = 206000: loss = 20593.703125
# step = 206000: Average Return = -1812.5999755859375
# Avg of Steps/Episode: 17.86
# step = 207000: loss = 22969.03515625
# step = 207000: Average Return = -1306.9000244140625
# Avg of Steps/Episode: 18.87
# step = 208000: loss = 1961.3896484375
# step = 208000: Average Return = -1026.5
# Avg of Steps/Episode: 17.24
# step = 209000: loss = 9388.4111328125
# step = 209000: Average Return = -2362.699951171875
# Avg of Steps/Episode: 15.15
# step = 210000: loss = 29190.580078125
# step = 210000: Average Return = -1336.0999755859375
# Avg of Steps/Episode: 15.15
# step = 211000: loss = 1939.15478515625
# step = 211000: Average Return = -1861.9000244140625
# Avg of Steps/Episode: 16.67
# step = 212000: loss = 30011.654296875
# step = 212000: Average Return = -2116.89990234375
# Avg of Steps/Episode: 16.13
# step = 213000: loss = 8042.92138671875
# step = 213000: Average Return = -1822.4000244140625
# Avg of Steps/Episode: 15.87
# step = 214000: loss = 11933.130859375
# step = 214000: Average Return = -1851.800048828125
# Avg of Steps/Episode: 16.95
# step = 215000: loss = 21797.171875
# step = 215000: Average Return = -1562.300048828125
# Avg of Steps/Episode: 16.13
# step = 216000: loss = 19326.251953125
# step = 216000: Average Return = -1301.800048828125
# Avg of Steps/Episode: 15.62
# step = 217000: loss = 3219.4306640625
# step = 217000: Average Return = -1586.9000244140625
# Avg of Steps/Episode: 17.24
# step = 218000: loss = 50804.33984375
# step = 218000: Average Return = -2166.60009765625
# Avg of Steps/Episode: 17.24
# step = 219000: loss = 67717.9765625
# step = 219000: Average Return = -1960.0
# Avg of Steps/Episode: 15.87
# step = 220000: loss = 27109.337890625
# step = 220000: Average Return = -2245.0
# Avg of Steps/Episode: 17.24
# step = 221000: loss = 1138.66064453125
# step = 221000: Average Return = -2092.5
# Avg of Steps/Episode: 17.86
# step = 222000: loss = 12654.0107421875
# step = 222000: Average Return = -2122.300048828125
# Avg of Steps/Episode: 17.54
# step = 223000: loss = 11470.3896484375
# step = 223000: Average Return = -2077.89990234375
# Avg of Steps/Episode: 16.95
# step = 224000: loss = 8909.1513671875
# step = 224000: Average Return = -1557.4000244140625
# Avg of Steps/Episode: 17.86
# step = 225000: loss = 7789.43603515625
# step = 225000: Average Return = -2500.0
# Avg of Steps/Episode: 20.00
# step = 226000: loss = 2153.628173828125
# step = 226000: Average Return = -1523.0999755859375
# Avg of Steps/Episode: 18.87
# step = 227000: loss = 6531.11669921875
# step = 227000: Average Return = -1876.800048828125
# Avg of Steps/Episode: 16.39
# step = 228000: loss = 33609.546875
# step = 228000: Average Return = -2407.199951171875
# Avg of Steps/Episode: 15.87
# step = 229000: loss = 6692.75048828125
# step = 229000: Average Return = -1861.9000244140625
# Avg of Steps/Episode: 18.18
# step = 230000: loss = 17555.119140625
# step = 230000: Average Return = -1537.9000244140625
# Avg of Steps/Episode: 18.18
# step = 231000: loss = 38267.13671875
# step = 231000: Average Return = -2210.10009765625
# Avg of Steps/Episode: 15.15
# step = 286000: loss = 44532.77734375
# step = 286000: Average Return = -1066.0999755859375
# Avg of Steps/Episode: 16.13
# step = 287000: loss = 18412.265625
# step = 287000: Average Return = -2073.300048828125
# Avg of Steps/Episode: 20.00
# step = 288000: loss = 11221.953125
# step = 288000: Average Return = -2525.0
# Avg of Steps/Episode: 20.41
# step = 289000: loss = 15458.60546875
# step = 289000: Average Return = -1886.300048828125
# Avg of Steps/Episode: 18.52
# step = 290000: loss = 2246.15087890625
# step = 290000: Average Return = -1552.5
# Avg of Steps/Episode: 19.23
# step = 291000: loss = 7798.9619140625
# step = 291000: Average Return = -2225.10009765625
# Avg of Steps/Episode: 17.54
# step = 292000: loss = 27221.013671875
# step = 292000: Average Return = -1915.0
# Avg of Steps/Episode: 17.24
# step = 293000: loss = 59182.58203125
# step = 293000: Average Return = -1557.4000244140625
# Avg of Steps/Episode: 17.54
# step = 294000: loss = 7591.57421875
# step = 294000: Average Return = -2058.60009765625
# Avg of Steps/Episode: 16.67
# step = 295000: loss = 7453.359375
# step = 295000: Average Return = -2082.89990234375
# Avg of Steps/Episode: 16.39
# step = 296000: loss = 12192.3251953125
# step = 296000: Average Return = -2535.0
# Avg of Steps/Episode: 16.39
# step = 297000: loss = 12589.8515625
# step = 297000: Average Return = -1856.5999755859375
# Avg of Steps/Episode: 18.18
# step = 298000: loss = 27406.72265625
# step = 298000: Average Return = -1861.9000244140625
# Avg of Steps/Episode: 20.00
# step = 299000: loss = 1043.5302734375
# step = 299000: Average Return = -1866.0999755859375
# Avg of Steps/Episode: 20.00
# step = 300000: loss = 11256.7041015625
# step = 300000: Average Return = -2200.699951171875
# Avg of Steps/Episode: 18.18
# step = 301000: loss = 16686.494140625
# step = 301000: Average Return = -2525.0
# Avg of Steps/Episode: 18.87
# step = 302000: loss = 13960.94140625
# step = 302000: Average Return = -2225.300048828125
# Avg of Steps/Episode: 18.18
# step = 303000: loss = 20863.197265625
# step = 303000: Average Return = -1596.5999755859375
# Avg of Steps/Episode: 15.38
# step = 304000: loss = 26329.30859375
# step = 304000: Average Return = -1812.9000244140625
# Avg of Steps/Episode: 17.24
# step = 305000: loss = 6619.1787109375
# step = 305000: Average Return = -1817.699951171875
# Avg of Steps/Episode: 18.52
# step = 306000: loss = 11094.615234375
# step = 306000: Average Return = -1370.4000244140625
# Avg of Steps/Episode: 17.86
# step = 307000: loss = 21209.705078125
# step = 307000: Average Return = -1022.0999755859375
# Avg of Steps/Episode: 17.24
# step = 308000: loss = 20019.0234375
# step = 308000: Average Return = -1890.9000244140625
# Avg of Steps/Episode: 15.38
# step = 309000: loss = 1723.0784912109375
# step = 309000: Average Return = -2230.0
# Avg of Steps/Episode: 17.86
# step = 310000: loss = 13549.3994140625
# step = 310000: Average Return = -756.7999877929688
# Avg of Steps/Episode: 20.00
# step = 311000: loss = 1266.98046875
# step = 311000: Average Return = -2200.300048828125
# Avg of Steps/Episode: 18.52
# step = 312000: loss = 1774.2274169921875
# step = 312000: Average Return = -1822.5
# Avg of Steps/Episode: 17.86
# step = 448000: Average Return = -1822.4000244140625
# Avg of Steps/Episode: 16.39
# step = 449000: loss = 3353.562744140625
# step = 449000: Average Return = -1022.2000122070312
# Avg of Steps/Episode: 15.15
# step = 450000: loss = 16218.267578125
# step = 450000: Average Return = -2073.10009765625
# Avg of Steps/Episode: 16.95
# step = 451000: loss = 10565.572265625
# step = 451000: Average Return = -2132.0
# Avg of Steps/Episode: 17.86
# step = 452000: loss = 2057.1337890625
# step = 452000: Average Return = -2372.699951171875
# Avg of Steps/Episode: 17.24
# step = 453000: loss = 14012.8427734375
# step = 453000: Average Return = -1547.4000244140625
# Avg of Steps/Episode: 17.24
# step = 454000: loss = 10328.396484375
# step = 454000: Average Return = -1596.699951171875
# Avg of Steps/Episode: 17.24
# step = 455000: loss = 9547.697265625
# step = 455000: Average Return = -1292.199951171875
# Avg of Steps/Episode: 16.67
# step = 456000: loss = 9029.337890625
# step = 456000: Average Return = -1060.5
# Avg of Steps/Episode: 14.71
# step = 457000: loss = 6998.0869140625
# step = 457000: Average Return = -2225.300048828125
# Avg of Steps/Episode: 16.13
# step = 458000: loss = 47336.59765625
# step = 458000: Average Return = -1370.9000244140625
# Avg of Steps/Episode: 18.18
# step = 459000: loss = 35143.2265625
# step = 459000: Average Return = -1955.0
# Avg of Steps/Episode: 17.86
# step = 460000: loss = 10212.865234375
# step = 460000: Average Return = -2367.5
# Avg of Steps/Episode: 19.61
# step = 461000: loss = 22849.890625
# step = 461000: Average Return = -1837.199951171875
# Avg of Steps/Episode: 17.54
# step = 462000: loss = 17607.595703125
# step = 462000: Average Return = -2127.199951171875
# Avg of Steps/Episode: 17.24
# step = 463000: loss = 27152.048828125
# step = 463000: Average Return = -1282.0999755859375
# Avg of Steps/Episode: 19.23
# step = 464000: loss = 15893.49609375
# step = 464000: Average Return = -1798.0
# Avg of Steps/Episode: 14.93
# step = 465000: loss = 11157.10546875
# step = 465000: Average Return = -2372.699951171875
# Avg of Steps/Episode: 15.15
# step = 466000: loss = 9217.791015625
# step = 466000: Average Return = -1866.5
# Avg of Steps/Episode: 19.61
# step = 467000: loss = 7868.7734375
# step = 467000: Average Return = -2343.199951171875
# Avg of Steps/Episode: 19.23
# step = 468000: loss = 29154.109375
# step = 468000: Average Return = -2117.300048828125
# Avg of Steps/Episode: 18.18
# step = 469000: loss = 2212.839111328125
# step = 469000: Average Return = -1287.0999755859375
# Avg of Steps/Episode: 15.15
# step = 470000: loss = 31540.95703125
# step = 470000: Average Return = -1817.800048828125
# Avg of Steps/Episode: 15.62
# step = 471000: loss = 14602.0390625
# step = 471000: Average Return = -1620.0999755859375
# Avg of Steps/Episode: 14.93
# step = 472000: loss = 9929.7978515625
# step = 472000: Average Return = -2235.0
# Avg of Steps/Episode: 14.71
# step = 473000: loss = 34565.5
# step = 473000: Average Return = -2107.5
# Avg of Steps/Episode: 19.61
# step = 474000: loss = 23506.8203125
# step = 474000: Average Return = -1571.9000244140625
# Avg of Steps/Episode: 18.52
# step = 475000: loss = 16924.7890625
# ## Visualization

# %%
import pandas as pd

# %%
# Loss - média móvel
# Ela serve para suavizar as flutuações de curto prazo em um conjunto de dados, 
# revelando a tendência subjacente e facilitando a identificação de pontos de reversão.
return_df = pd.DataFrame({'return': returns}) 

periodo_media_movel = 10
return_df['media_movel'] = return_df['return'].rolling(window=periodo_media_movel).mean()

plt.figure(figsize=(10, 6))
plt.plot(return_df['return'], label='Valores Originais', marker='o')
plt.plot(return_df['media_movel'], label=f'Média Móvel ({periodo_media_movel} períodos)', linestyle='dashed')
plt.xlabel('Período')
plt.ylabel('Return')
plt.title('Média Móvel do return')
plt.legend()
plt.grid(axis='y')
#plt.ylim(top=100, bottom=-50)
plt.show()

# %%
# Loss - média móvel
# Ela serve para suavizar as flutuações de curto prazo em um conjunto de dados, 
# revelando a tendência subjacente e facilitando a identificação de pontos de reversão.
loss_df = pd.DataFrame({'loss': loss_log}) 

periodo_media_movel = 10
loss_df['media_movel'] = loss_df['loss'].rolling(window=periodo_media_movel).mean()

plt.figure(figsize=(10, 6))
plt.plot(loss_df['loss'], label='Valores Originais', marker='o')
plt.plot(loss_df['media_movel'], label=f'Média Móvel ({periodo_media_movel} períodos)', linestyle='dashed')
plt.xlabel('Período')
plt.ylabel('Loss')
plt.title('Média Móvel da Loss')
plt.legend()
plt.grid(axis='y')
#plt.ylim(top=5000, bottom=0)
plt.show()

# %%
iterations = range(0, num_iterations, log_interval)
plt.plot(iterations, episodes_per_log_interval)
plt.ylabel('Episodes per log interval/iterations') 
plt.xlabel('Iterations')
#plt.ylim(top=50)
plt.show()

# %%
iterations = range(0, num_iterations, eval_interval)
plt.plot(iterations, avg_steps_per_episode_per_eval_interval)
plt.ylabel('Average Steps per Episode') 
plt.xlabel('Iterations')
# Out:
# Text(0.5, 0, 'Iterations')

# %%
iterations = range(0, num_iterations, eval_interval)
plt.plot(iterations, my_metric_log)
plt.ylabel('Cumulative Crashes') 
plt.xlabel('Iterations')
# Out:
# Text(0.5, 0, 'Iterations')

# %%
def embed_mp4(filename):
  """Embeds an mp4 file in the notebook."""
  video = open(filename,'rb').read()
  b64 = base64.b64encode(video)
  tag = '''
  <video width="640" height="480" controls>
    <source src="data:video/mp4;base64,{0}" type="video/mp4">
  Your browser does not support the video tag.
  </video>'''.format(b64.decode())

  return IPython.display.HTML(tag)

# %%
def create_policy_eval_video(policy, filename, num_episodes=10, fps=24):
  filename = filename + ".mp4"
  with imageio.get_writer(filename, fps=fps) as video:
    for _ in range(num_episodes):
      time_step = eval_env.reset()
      video.append_data(eval_py_env.render())
      while not time_step.is_last():
        action_step = policy.action(time_step)
        time_step = eval_env.step(action_step.action)
        video.append_data(eval_py_env.render())
  return embed_mp4(filename)

# Gera video da politica do agente treinado até então
create_policy_eval_video(agent.policy, "trained-agent")
# Out:
# WARNING:root:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (700, 700) to (704, 704) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to None (risking incompatibility). You may also see a FFMPEG warning concerning speedloss due to data not being aligned.
#   <video width="640" height="480" controls>
#     <source src="data:video/mp4;base64,..." type="video/mp4">
#   Your browser does not support the video tag.
#   </video>

# %% [markdown]
# ### Keep Training

# %% [markdown]
# # MazeDrone with TF Agents - 2002 Walls Checkpoint (Reward 3)

# %%
from __future__ import absolute_import, division, print_function

import os
# Keep using keras-2 (tf-keras) rather than keras-3 (keras).
os.environ['TF_USE_LEGACY_KERAS'] = '1'




import matplotlib.pyplot as plt
import numpy as np
import PIL.Image

import tensorflow as tf
from tf_agents.agents.dqn import dqn_agent
from tf_agents.environments import suite_gym
from tf_agents.environments import tf_py_environment
from tf_agents.metrics import tf_metrics
from tf_agents.utils import common

import sys
import gym

from resources import build_agent, TrainingSession
import pandas as pd
import gc

# %%
min_combination = 3 # combination 3
min_run = 1
max_run = 1


num_iterations = 20_000 # @param {type:"integer"}

initial_collect_steps = 64  # @param {type:"integer"}
collect_steps_per_iteration = 5 # @param {type:"integer"}
#replay_buffer_max_length = 100000  # @param {type:"integer"}
replay_buffer_max_length = 100  # @param {type:"integer"}

batch_size = 64  # @param {type:"integer"}
learning_rate = 1e-3  # @param {type:"number"}
log_interval = 100  # @param {type:"integer"}

num_eval_episodes = 10  # @param {type:"integer"}
eval_interval = 100  # @param {type:"integer"}

# Agent fully connected layer params 
fc_layer_params = (200,) 

# File's name
description = "3002"

maze_size = 3

rewards = []
rewards.append({
    'destroyed': -10.,
    'stuck': - 6.,
    'reached': 10.,
    'standard': -1.
})
rewards.append({
    'destroyed': -10.,
    'stuck': -11.,
    'reached': 10.,
    'standard': -1.
})
rewards.append({
    'destroyed': -10.,
    'stuck': -15.,
    'reached': 10.,
    'standard': -1.
})


sys.path.append('/home/naski/Documents/dev/maze_drone_v02')
import gym_maze # Esta linha precisa estar após o PATH

# Importing custom environment
env_name = 'maze-v0'
env = suite_gym.load(env_name)

# Testing
env.reset()

train_py_env = suite_gym.load(env_name)
# Converts environments, originally in pure Python, to tensors (using a wrapper)
train_env = tf_py_environment.TFPyEnvironment(train_py_env)





# CREATING/RESETING THE AGENT
agent = build_agent(fc_layer_params, env, learning_rate, train_env)
agent.initialize()

# GENERATE TRAINING SESSION
session = TrainingSession(description, maze_size, env_name, rewards[0], agent, collect_steps_per_iteration, 
                        1, eval_interval, replay_buffer_max_length, num_eval_episodes)

# TRAINING
step_log, returns, finished, crashed, stucked, steped, _, replay_buffer, _ = session.train()

# CLEAR MEMORY
del(session)
# Out:
# Rewards Updated: {'destroyed': -10.0, 'stuck': -6.0, 'reached': 10.0, 'standard': -1.0}
# Rewards Updated: {'destroyed': -10.0, 'stuck': -6.0, 'reached': 10.0, 'standard': -1.0}
# Mode set: 1
# Mode set: 1
# Maze site set: 3x3
# Maze site set: 3x3
# Rewards: {'destroyed': -10.0, 'stuck': -6.0, 'reached': 10.0, 'standard': -1.0}
# learning_rate inside: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>

# %%
print("============================================================== After first training:")

print(agent.train_step_counter)

checkpoint_dir = './checkpoint/phase-2-1-stuck'
train_checkpointer = common.Checkpointer(
    ckpt_dir=checkpoint_dir,
    max_to_keep=1,
    agent=agent,
    policy=agent.policy,
    replay_buffer=replay_buffer,
    global_step=agent.train_step_counter
)

print(agent.train_step_counter)


train_checkpointer.initialize_or_restore()
    
print(agent.train_step_counter)

agent._optimizer.learning_rate = learning_rate
print(agent._optimizer.learning_rate)
# Out:
# ============================================================== After first training:
# <tf.Variable 'Variable:0' shape=() dtype=int32, numpy=1>
# <tf.Variable 'Variable:0' shape=() dtype=int32, numpy=2700>
# <tf.Variable 'Variable:0' shape=() dtype=int32, numpy=2700>
# <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>

# %%
print("========================================================================== Training:")


for combination in range(min_combination-1, min_combination):

    for run in range(min_run-1, max_run):
        print('Combination', combination + 1, ' | Run', run + 1)
        train_checkpointer = common.Checkpointer(
            ckpt_dir=checkpoint_dir,
            max_to_keep=1,
            agent=agent,
            policy=agent.policy,
            replay_buffer=replay_buffer,
            global_step=agent.train_step_counter
        )
        agent._optimizer.learning_rate = learning_rate
        print(agent.train_step_counter)


        # GENERATE TRAINING SESSION
        session = TrainingSession(description, maze_size, env_name, rewards[combination], agent, collect_steps_per_iteration, 
                                num_iterations, eval_interval, replay_buffer_max_length, num_eval_episodes)
        
        # TRAINING
        step_log, returns, finished, crashed, stucked, steped, log_loss, _, agent = session.train(without_wall_training=False, early_stop="stuckANDcrash")

        # LOGGING
        df_log = pd.DataFrame({'Step': step_log, 'Average Return': returns, '% Finished': finished, 'Crash Counter': crashed, 'Stuck Counter': stucked, 'Avg Steps/Episode': steped, 'Loss log': log_loss})
        df_log.to_csv(f"logs/04-stateChange/{description}_comb-{combination+1}-run-{run+1}.csv", index=None, header=True)

        # CLEAR MEMORY
        #del(agent)
        #del(session)
        #del(df_log)
        #gc.collect()
# Out:
# ========================================================================== Training:
# Combination 3  | Run 1
# <tf.Variable 'Variable:0' shape=() dtype=int32, numpy=2700>
# Rewards Updated: {'destroyed': -10.0, 'stuck': -15.0, 'reached': 10.0, 'standard': -1.0}
# Rewards Updated: {'destroyed': -10.0, 'stuck': -15.0, 'reached': 10.0, 'standard': -1.0}
# Mode set: 0
# Mode set: 0
# Maze site set: 3x3
# Maze site set: 3x3
# Rewards: {'destroyed': -10.0, 'stuck': -15.0, 'reached': 10.0, 'standard': -1.0}
# step = 2800
# Early stop reseted at 2800
# step = 2900
# Early stop reseted at 2900
# step = 3000
# step = 3000
# Early stop reseted at 3000
# step = 3100
# Early stop reseted at 3100
# step = 3200
# Early stop reseted at 3200
# step = 3300
# Early stop reseted at 3300
# step = 3400
# Early stop reseted at 3400
# step = 3500
# Early stop reseted at 3500
# step = 3600
# Early stop reseted at 3600
# step = 3700
# Early stop reseted at 3700
# step = 3800
# Early stop reseted at 3800
# step = 3900
# Early stop reseted at 3900
# step = 4000
# step = 4000
# Early stop reseted at 4000
# step = 4100
# Early stop reseted at 4100
# step = 4200
# Early stop reseted at 4200
# step = 4300
# Early stop reseted at 4300
# step = 4400
# Early stop reseted at 4400
# step = 4500
# Early stop reseted at 4500
# step = 4600
# Early stop reseted at 4600
# step = 4700
# Early stop reseted at 4700
# step = 4800
# Early stop reseted at 4800
# step = 4900
# Early stop reseted at 4900
# step = 5000
# step = 5000
# Early stop reseted at 5000
# step = 5100
# Early stop reseted at 5100
# step = 5200
# Early stop reseted at 5200
# step = 5300
# Early stop reseted at 5300
# step = 5400
# Early stop reseted at 5400
# step = 5500
# Early stop reseted at 5500
# step = 5600
# Early stop reseted at 5600
# step = 5700
# Early stop reseted at 5700
# step = 5800
# Early stop reseted at 5800
# step = 5900
# Early stop reseted at 5900
# step = 6000
# step = 6000
# Early stop reseted at 6000
# step = 6100
# Early stop reseted at 6100
# step = 6200
# Early stop reseted at 6200
# step = 6300
# Early stop reseted at 6300
# step = 6400
# Early stop reseted at 6400
# step = 6500
#
# =====================================================================( 1 )
# Small check log:
# Avg return: -17.6
# Finished: 0.8
# Crash Counter: 11
# Stuck counter: 2
# ==========================================================================
#
# step = 6600
# Early stop reseted at 6600
# step = 6700
# Early stop reseted at 6700
# step = 6800
# Early stop reseted at 6800
# step = 6900
# Early stop reseted at 6900
# step = 7000
# step = 7000
# Early stop reseted at 7000
# step = 7100
# Early stop reseted at 7100
# step = 7200
#
# =====================================================================( 1 )
# Small check log:
# Avg return: 5.4
# Finished: 1.0
# Crash Counter: 0
# Stuck counter: 1
# ==========================================================================
#
# step = 7300
# Early stop reseted at 7300
# step = 7400
#
# =====================================================================( 1 )
# Small check log:
# Avg return: -13.7
# Finished: 0.9
# Crash Counter: 0
# Stuck counter: 11
# ==========================================================================
#
# step = 7500
#
# =====================================================================( 2 )
# Small check log:
# Avg return: -17.0
# Finished: 0.7
# Crash Counter: 9
# Stuck counter: 0
# ==========================================================================
#
# step = 7600
# Early stop reseted at 7600
# step = 7700
# Early stop reseted at 7700
# step = 7800
# Early stop reseted at 7800
# step = 7900
#
# =====================================================================( 1 )
# Small check log:
# Avg return: -36.1
# Finished: 0.5
# Crash Counter: 17
# Stuck counter: 0
# ==========================================================================
#
# step = 8000
# step = 8000
# Early stop reseted at 8000
# step = 8100
#
# =====================================================================( 1 )
# Small check log:
# Avg return: -0.5
# Finished: 0.9
# Crash Counter: 0
# Stuck counter: 1
# ==========================================================================
#
# step = 8200
#
# =====================================================================( 2 )
# Small check log:
# Avg return: -18.0
# Finished: 0.7
# Crash Counter: 6
# Stuck counter: 1
# ==========================================================================
#
# step = 8300
#
# =====================================================================( 3 )
# Small check log:
# Avg return: -81.8
# Finished: 0.7
# Crash Counter: 25
# Stuck counter: 35
# ==========================================================================
#
# step = 8400
# Early stop reseted at 8400
# step = 8500
#
# =====================================================================( 1 )
# Small check log:
# Avg return: -8.4
# Finished: 0.9
# Crash Counter: 11
# Stuck counter: 0
# ==========================================================================
#
# step = 8600
# Early stop reseted at 8600
# step = 8700
#
# =====================================================================( 1 )
# Small check log:
# Avg return: 5.9
# Finished: 1.0
# Crash Counter: 0
# Stuck counter: 0
# ==========================================================================
#
# step = 8800
# Early stop reseted at 8800
# step = 8900
# Early stop reseted at 8900
# step = 9000
# step = 9000
# Early stop reseted at 9000
# step = 9100
# Early stop reseted at 9100
# step = 9200
# Early stop reseted at 9200
# step = 9300
# Early stop reseted at 9300
# step = 9400
#
# =====================================================================( 1 )
# Small check log:
# Avg return: 4.0
# Finished: 1.0
# Crash Counter: 2
# Stuck counter: 0
# ==========================================================================
#
# step = 9500
# Early stop reseted at 9500
# step = 9600
#
# =====================================================================( 1 )
# Small check log:
# Avg return: -6.5
# Finished: 0.9
# Crash Counter: 10
# Stuck counter: 0
# ==========================================================================
#
# step = 9700
#
# =====================================================================( 2 )
# Small check log:
# Avg return: -9.3
# Finished: 0.7
# Crash Counter: 0
# Stuck counter: 0
# ==========================================================================
#
# step = 9800
# Early stop reseted at 9800
# step = 9900
# Early stop reseted at 9900
# step = 10000
# step = 10000
#
# =====================================================================( 1 )
# Small check log:
# Avg return: 2.7
# Finished: 0.9
# Crash Counter: 0
# Stuck counter: 0
# ==========================================================================
#
# step = 10100
# Early stop reseted at 10100
# step = 10200
# Early stop reseted at 10200
# step = 10300
# Early stop reseted at 10300
# step = 10400
#
# =====================================================================( 1 )
# Small check log:
# Avg return: -10.8
# Finished: 0.8
# Crash Counter: 7
# Stuck counter: 0
# ==========================================================================
#
# step = 10500
# Early stop reseted at 10500
# step = 10600
#
# =====================================================================( 1 )
# Small check log:
# Avg return: -8.8
# Finished: 0.8
# Crash Counter: 6
# Stuck counter: 0
# ==========================================================================
#
# step = 10700
# Early stop reseted at 10700
# step = 10800
#
# =====================================================================( 1 )
# Small check log:
# Avg return: 1.0
# Finished: 0.9
# Crash Counter: 0
# Stuck counter: 0
# ==========================================================================
#
# step = 10900
# Early stop reseted at 10900
# step = 11000
# step = 11000
# Early stop reseted at 11000
# step = 11100
#
# =====================================================================( 1 )
# Small check log:
# Avg return: 7.3
# Finished: 1.0
# Crash Counter: 0
# Stuck counter: 0
# ==========================================================================
#
# step = 11200
# Early stop reseted at 11200
# step = 11300
#
# =====================================================================( 1 )
# Small check log:
# Avg return: 1.6
# Finished: 0.9
# Crash Counter: 0
# Stuck counter: 0
# ==========================================================================
#
# step = 11400
#
# =====================================================================( 2 )
# Small check log:
# Avg return: -4.2
# Finished: 0.8
# Crash Counter: 0
# Stuck counter: 0
# ==========================================================================
#
# step = 11500
#
# =====================================================================( 3 )
# Small check log:
# Avg return: -9.4
# Finished: 0.8
# Crash Counter: 7
# Stuck counter: 0
# ==========================================================================
#
# step = 11600
# Early stop reseted at 11600
# step = 11700
#
# =====================================================================( 1 )
# Small check log:
# Avg return: -12.1
# Finished: 0.8
# Crash Counter: 5
# Stuck counter: 2
# ==========================================================================
#
# step = 11800
#
# =====================================================================( 2 )
# Small check log:
# Avg return: -16.4
# Finished: 0.8
# Crash Counter: 14
# Stuck counter: 0
# ==========================================================================
#
# step = 11900
#
# =====================================================================( 3 )
# Small check log:
# Avg return: 6.8
# Finished: 1.0
# Crash Counter: 0
# Stuck counter: 0
# ==========================================================================
#
# step = 12000
# step = 12000
# Early stop reseted at 12000
# step = 12100
#
# =====================================================================( 1 )
# Small check log:
# Avg return: -7.0
# Finished: 0.9
# Crash Counter: 9
# Stuck counter: 0
# ==========================================================================
#
# step = 12200
#
# =====================================================================( 2 )
# Small check log:
# Avg return: 0.5
# Finished: 0.9
# Crash Counter: 0
# Stuck counter: 0
# ==========================================================================
#
# step = 12300
#
# =====================================================================( 3 )
# Small check log:
# Avg return: -4.2
# Finished: 0.8
# Crash Counter: 0
# Stuck counter: 0
# ==========================================================================
#
# step = 12400
#
# =====================================================================( 4 )
# Small check log:
# Avg return: 6.9
# Finished: 1.0
# Crash Counter: 0
# Stuck counter: 0
# ==========================================================================
#
# step = 12500
#
# =============================================================( EARLY STOP )
# Big check log:
# Avg return: 0.72
# Finished: 0.92
# Crash Counter: 4
# Stuck counter: 15
# Early stop at 12500
# ==========================================================================
#
# learning_rate inside: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>

# %%
from resources import plot_moving_avg, plot_metric_per_iteration
plot_moving_avg('return', returns)

# %%
plot_moving_avg('crashed', crashed)

# %%
plot_moving_avg('stucked', stucked)

# %%
plot_moving_avg('loss', log_loss, ylim=True, top_lim=1_00)

# %%
from resources import create_policy_eval_video

# Reset the environment.
time_step = train_py_env.reset()
train_py_env.set_mode(1)
train_py_env.set_size(maze_size)


# Gera video da politica do agente treinado até então
create_policy_eval_video(agent.policy, f"trained-agent-{description}", train_env, train_py_env)
# Out:
# Mode set: 1
# Maze site set: 3x3
# WARNING:root:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (700, 700) to (704, 704) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to None (risking incompatibility). You may also see a FFMPEG warning concerning speedloss due to data not being aligned.
#     <video width="640" height="480" controls>
#     <source src="data:video/mp4;base64,..." type="video/mp4">
#     Your browser does not support the video tag.
#     </video>

# %%
from resources import create_policy_eval_video
# Reset the environment.
time_step = train_py_env.reset()
train_py_env.set_mode(0)
train_py_env.set_size(maze_size)


# Gera video da politica do agente treinado até então
create_policy_eval_video(agent.policy, f"trained-agent-{description}", train_env, train_py_env)
# Out:
# Mode set: 0
# Maze site set: 3x3
# WARNING:root:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (700, 700) to (704, 704) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to None (risking incompatibility). You may also see a FFMPEG warning concerning speedloss due to data not being aligned.
#     <video width="640" height="480" controls>
#     <source src="data:video/mp4;base64,..." type="video/mp4">
#     Your browser does not support the video tag.
#     </video>

# %%
checkpoint_dir = './checkpoint/phase-2-5-stuck'

train_checkpointer = common.Checkpointer(
    ckpt_dir=checkpoint_dir,
    max_to_keep=1,
    agent=agent,
    policy=agent.policy,
    replay_buffer=replay_buffer,
    global_step=agent.train_step_counter
)

# %%
train_checkpointer.save(agent.train_step_counter)

# %%
# Reset the environment.
time_step = train_py_env.reset()
train_py_env.set_mode(0)
train_py_env.set_size(maze_size)


# Gera video da politica do agente treinado até então
create_policy_eval_video(agent.policy, f"trained-agent3-{description}", train_env, train_py_env)
# Out:
# WARNING:root:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (700, 700) to (704, 704) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to None (risking incompatibility). You may also see a FFMPEG warning concerning speedloss due to data not being aligned.
# Mode set: 0
# Maze site set: 3x3
#     <video width="640" height="480" controls>
#     <source src="data:video/mp4;base64,..." type="video/mp4">
#     Your browser does not support the video tag.
#     </video>

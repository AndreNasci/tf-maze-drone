# %%
import os
# Keep using keras-2 (tf-keras) rather than keras-3 (keras).
os.environ['TF_USE_LEGACY_KERAS'] = '1'

# %%
import PIL.Image
from tf_agents.environments import suite_gym
# Out:
# 2024-06-06 16:41:45.442760: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-06 16:41:45.446597: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-06 16:41:45.499839: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-06 16:41:46.626396: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Some necessary imports 
import sys
sys.path.append('/home/naski/Documents/dev/maze_drone_v02')

import gym_maze

# %%
# Importing custom environment
env_name = 'maze-v0'
env = suite_gym.load(env_name)

# %%
_ = env.reset()
PIL.Image.fromarray(env.render())
# Out:
# <PIL.Image.Image image mode=RGBA size=700x700>

# %%
env.render(mode='human')
# Out:
#  B0   R1   T2   L3
# [0.0, 1.0, 1.0, 0.0, 3.0]

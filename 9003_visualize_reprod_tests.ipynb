# %% [markdown]
# # MazeDrone with TF Agents - 9003 Vizualize Logs from 9002

# %%
import pandas as pd

# %%
resumos = []

for i in range(5):
    read_file = pd.read_csv(f"logs/05-validating-reprod/resumo-9002-checkpoint_3-run_2-log_{i+1}.csv")
        
        
    resumos.append(pd.DataFrame(read_file))

# %%
df_resumo = pd.concat(resumos)

# %%
df_resumo
# Out:
#    run  check_1  check_2  check_3  check_4  avg_return  finished_percentage  \
# 0    1     2000     2700    17300    18000       0.691                0.882
# 1    2     1900     2800    16500    17100      -1.807                0.833
# 0    1     1400     2400    19500    22000       3.127                0.931
# 1    2     1800     2500    16800    17300       1.973                0.903
# 0    1     2300     2800    23200    33000       2.290                0.918
# 1    2     1800     2300    15500    16000       1.462                0.917
# 0    1     2100     2600    13600    14700       2.495                0.914
# 1    2     1700     2200    12600    13500       2.749                0.915
# 0    1     1500     2500    23700    24200       2.360                0.906
# 1    2     2400     3400    10100    24200      -0.715                0.868
#
#    crashes_counter  stuck_counter  avg_steps
# 0                0             13      8.829
# ...

# %%
resumos = []

for i in range(5):
    read_file = pd.read_csv(f"logs/05-validating-reprod/resumo-9002-checkpoint_4-run_2-log_{i+1}.csv")
        
        
    resumos.append(pd.DataFrame(read_file))

# %%
df_resumo = pd.concat(resumos)

# %%
df_resumo
# Out:
#    run  check_1  check_2  check_3  check_4  avg_return  finished_percentage  \
# 0    1     1900     2400    15500    16100       0.798                0.894
# 1    2     2500     3600    16700    17200       1.630                0.896
# 0    1     2400     2900    15000    17100       0.915                0.882
# 1    2     1500     2500    16100    24100      -0.283                0.873
# 0    1     1700     2300    26700    28100       2.470                0.910
# 1    2     1400     3600    23400    24000       1.095                0.908
# 0    1     1900     2900    12200    13000       2.823                0.922
# 1    2     1500     2900    16800    17600       2.283                0.921
# 0    1     1100     2500    14800    15700      -1.514                0.839
# 1    2     1300     1900    12600    13600      -1.002                0.853
#
#    crashes_counter  stuck_counter  avg_steps
# 0                0             47      8.378
# ...

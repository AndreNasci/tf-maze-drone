# %% [markdown]
# # MazeDrone with TF Agents
#
# First attempt with polar distance added.
#
# **Rewards:**
# - destroyed = -51.
# - stucked = 0.
# - reached_target = 300.
# - standard = -1.

# %% [markdown]
# ### Setup

# %%
import os
# Keep using keras-2 (tf-keras) rather than keras-3 (keras).
os.environ['TF_USE_LEGACY_KERAS'] = '1'

from __future__ import absolute_import, division, print_function



import matplotlib.pyplot as plt
import numpy as np
import PIL.Image

import tensorflow as tf
from tf_agents.agents.dqn import dqn_agent
from tf_agents.environments import suite_gym
from tf_agents.environments import tf_py_environment
from tf_agents.metrics import tf_metrics
# from tf_agents.networks import sequential
# from tf_agents.policies import random_tf_policy
# from tf_agents.specs import tensor_spec
from tf_agents.utils import common

import sys
import gym
import gym_maze
# Out:
# 2024-06-19 19:13:51.491308: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-19 19:13:51.655873: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-19 19:13:52.515056: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-19 19:13:55.894468: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ### Hyperparameters

# %%
num_iterations = 100_000 # @param {type:"integer"}

initial_collect_steps = 100  # @param {type:"integer"}
collect_steps_per_iteration = 1 # @param {type:"integer"}
#replay_buffer_max_length = 100000  # @param {type:"integer"}
replay_buffer_max_length = 100  # @param {type:"integer"}

batch_size = 64  # @param {type:"integer"}
learning_rate = 1e-3  # @param {type:"number"}
log_interval = 200  # @param {type:"integer"}

num_eval_episodes = 10  # @param {type:"integer"}
eval_interval = 1000  # @param {type:"integer"}

# %% [markdown]
# ### Environment

# %%
# Some necessary imports 
#sys.path.append('/home/naski/Documents/dev/maze_drone_v02/maze-drone-v02/lib/python3.10/site-packages')

# %%
# Importing custom environment
env_name = 'maze-v0'
env = suite_gym.load(env_name)

# Testing
env.reset()
# Out:
# TimeStep(
# {'step_type': array(0, dtype=int32),
#  'reward': array(0., dtype=float32),
#  'discount': array(1., dtype=float32),
#  'observation': array([1.       , 1.       , 0.       , 1.       , 1.4142135, 2.3561945],
#       dtype=float32)})

# %% [markdown]
# Usually two environments are instantiated: one for training and one for evaluation.

# %%
train_py_env = suite_gym.load(env_name)
eval_py_env = suite_gym.load(env_name)

# Converts environments, originally in pure Python, to tensors (using a wrapper)
train_env = tf_py_environment.TFPyEnvironment(train_py_env)
eval_env = tf_py_environment.TFPyEnvironment(eval_py_env)

# %% [markdown]
# ### Agent

# %%
from resources import build_agent

fc_layer_params = (200, 100, 50, ) # fc = fully connected
agent = build_agent(fc_layer_params, env, learning_rate, train_env)

agent.initialize()

# %% [markdown]
# ### Policies

# %%
# The main policy that is used for evaluation and deployment.
eval_policy = agent.policy
# A second policy that is used for data collection.
collect_policy = agent.collect_policy

# %% [markdown]
# ### Metrics and Evaluation

# %%
from resources import compute_avg_return

# %% [markdown]
# ### New Observer

# %%
from resources import MyMetric

# Create an instance of MyMetric
my_metric = MyMetric()

# %% [markdown]
# ### Replay Buffer

# %%
from tf_agents.drivers import dynamic_step_driver
from tf_agents.replay_buffers import tf_uniform_replay_buffer

# %%
replay_buffer_capacity = replay_buffer_max_length

replay_buffer = tf_uniform_replay_buffer.TFUniformReplayBuffer(
    agent.collect_data_spec,
    batch_size=train_env.batch_size,
    max_length=replay_buffer_capacity)

num_episodes = tf_metrics.NumberOfEpisodes()
env_steps = tf_metrics.EnvironmentSteps()

# Add an observer that adds to the replay buffer:
replay_observer = [replay_buffer.add_batch, num_episodes, env_steps, my_metric]

# %% [markdown]
# ### Data Collection

# %%
# Data collection:
collect_op = dynamic_step_driver.DynamicStepDriver(
  train_env,
  agent.collect_policy,
  observers=replay_observer,
  num_steps=collect_steps_per_iteration).run()

# %%
# Dataset generates trajectories with shape [Bx2x...]
dataset = replay_buffer.as_dataset(
    num_parallel_calls=3,
    sample_batch_size=batch_size,
    num_steps=2).prefetch(3)
# Out:
# WARNING:tensorflow:From /home/naski/Documents/dev/maze_drone_v02/maze-drone-v03/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py:377: ReplayBuffer.get_next (from tf_agents.replay_buffers.replay_buffer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `as_dataset(..., single_deterministic_pass=False) instead.

# %% [markdown]
# ### Training the Agent

# %%
# %%time

# (Optional) Optimize by wrapping some of the code in a graph using TF function.
agent.train = common.function(agent.train)

# Reset the train step.
agent.train_step_counter.assign(0)

# Evaluate the agent's policy once before training.
avg_return = compute_avg_return(eval_env, agent.policy, num_eval_episodes)
returns = [avg_return]

# Reset the environment.
time_step = train_py_env.reset()

# Create a driver to collect experience.
collect_driver = dynamic_step_driver.DynamicStepDriver(
    train_env,
    agent.collect_policy,
    observers=replay_observer,
    num_steps=collect_steps_per_iteration)

iterator = iter(dataset)

loss_log = []
step_log = []
steps_per_episode_log = []
episodes_per_log_interval = []
previous_n_episodes = 0

my_metric_log = []

avg_steps_per_episode_per_eval_interval = []

for _ in range(num_iterations):

    # Collect a few steps and save to the replay buffer.
    time_step, _ = collect_driver.run()

    # Sample a batch of data from the buffer and update the agent's network.
    trajectories, _ = next(iterator)
    train_loss = agent.train(experience=trajectories).loss

    step = agent.train_step_counter.numpy()

    if step % log_interval == 0:
        print('step = {0}: loss = {1}'.format(step, train_loss))
        step_log.append(step)
        loss_log.append(train_loss)
        episodes_per_log_interval.append(num_episodes.result().numpy() - previous_n_episodes)
        steps_per_episode_log.append(log_interval / (episodes_per_log_interval[-1]))
        previous_n_episodes = num_episodes.result().numpy()

    if step % eval_interval == 0:
        print('step = {0}: loss = {1}'.format(step, train_loss))
        avg_return = compute_avg_return(eval_env, agent.policy, num_eval_episodes)
        print('step = {0}: Average Return = {1}'.format(step, avg_return))
        returns.append(avg_return)
        avg_steps_per_episode_per_eval_interval.append(eval_interval / sum(episodes_per_log_interval[-10:]))
        print('Avg of Steps/Episode: {:.2f}'.format(avg_steps_per_episode_per_eval_interval[-1]) )

        current_value = my_metric.result()
        my_metric_log.append(current_value)
# Out:
# WARNING:tensorflow:From /home/naski/Documents/dev/maze_drone_v02/maze-drone-v03/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py:1260: calling foldr_v2 (from tensorflow.python.ops.functional_ops) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.foldr(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.foldr(fn, elems))
# step = 200: loss = 8152.1826171875
# step = 400: loss = 17894.880859375
# step = 600: loss = 10079.1005859375
# step = 800: loss = 4841.541015625
# step = 1000: loss = 4107.4091796875
# step = 1000: loss = 4107.4091796875
# step = 1000: Average Return = -2005.0
# Avg of Steps/Episode: 38.46
# step = 1200: loss = 8147.416015625
# step = 1400: loss = 9359.4658203125
# step = 1600: loss = 4730.75390625
# step = 1800: loss = 7096.44921875
# step = 2000: loss = 1962.2427978515625
# step = 2000: loss = 1962.2427978515625
# step = 2000: Average Return = -430.1000061035156
# Avg of Steps/Episode: 18.18
# step = 2200: loss = 2946.745849609375
# step = 2400: loss = 1445.18115234375
# step = 2600: loss = 1381.935546875
# step = 2800: loss = 1421.152587890625
# step = 3000: loss = 397.92413330078125
# step = 3000: loss = 397.92413330078125
# step = 3000: Average Return = -365.6000061035156
# Avg of Steps/Episode: 10.64
# step = 3200: loss = 1408.4031982421875
# step = 3400: loss = 1979.1685791015625
# step = 3600: loss = 1306.2818603515625
# step = 3800: loss = 720.5621337890625
# step = 4000: loss = 828.6802368164062
# step = 4000: loss = 828.6802368164062
# step = 4000: Average Return = 124.30000305175781
# Avg of Steps/Episode: 7.04
# step = 4200: loss = 2834.689453125
# step = 4400: loss = 1551.4671630859375
# step = 4600: loss = 945.2333984375
# step = 4800: loss = 1857.02392578125
# step = 5000: loss = 270.6596374511719
# step = 5000: loss = 270.6596374511719
# step = 5000: Average Return = 159.5
# Avg of Steps/Episode: 8.13
# step = 5200: loss = 878.7228393554688
# step = 5400: loss = 708.5257568359375
# step = 5600: loss = 1670.65771484375
# step = 5800: loss = 576.0526123046875
# step = 6000: loss = 968.0086669921875
# step = 6000: loss = 968.0086669921875
# step = 6000: Average Return = -21.299999237060547
# Avg of Steps/Episode: 12.99
# step = 6200: loss = 652.63134765625
# step = 6400: loss = 4478.22412109375
# step = 6600: loss = 805.276611328125
# step = 6800: loss = 1594.691650390625
# step = 7000: loss = 255.99505615234375
# step = 7000: loss = 255.99505615234375
# step = 7000: Average Return = 54.79999923706055
# Avg of Steps/Episode: 14.49
# step = 7200: loss = 423.3022766113281
# step = 7400: loss = 105.02223205566406
# step = 7600: loss = 217.74639892578125
# step = 7800: loss = 172.17251586914062
# step = 8000: loss = 874.3984985351562
# step = 8000: loss = 874.3984985351562
# step = 8000: Average Return = 193.60000610351562
# Avg of Steps/Episode: 11.11
# step = 8200: loss = 887.2865600585938
# step = 8400: loss = 228.86956787109375
# step = 8600: loss = 1052.940185546875
# step = 8800: loss = 155.29150390625
# step = 9000: loss = 2711.58447265625
# step = 9000: loss = 2711.58447265625
# step = 9000: Average Return = 124.30000305175781
# Avg of Steps/Episode: 9.80
# step = 9200: loss = 98.08885192871094
# step = 9400: loss = 237.17481994628906
# step = 9600: loss = 956.0849609375
# step = 9800: loss = 23531724.0
# step = 10000: loss = 114295328.0
# step = 10000: loss = 114295328.0
# step = 10000: Average Return = -2250.0
# Avg of Steps/Episode: 11.76
# step = 10200: loss = 37780664.0
# step = 10400: loss = 75177728.0
# step = 10600: loss = 117155488.0
# step = 10800: loss = 99730288.0
# step = 11000: loss = 10771472.0
# step = 11000: loss = 10771472.0
# step = 11000: Average Return = -2260.0
# Avg of Steps/Episode: 16.13
# step = 11200: loss = 8805493.0
# step = 11400: loss = 7392073.0
# step = 11600: loss = 6202682.0
# step = 11800: loss = 1936045.75
# step = 12000: loss = 712837.625
# step = 12000: loss = 712837.625
# step = 12000: Average Return = -1200.0
# Avg of Steps/Episode: 16.67
# step = 12200: loss = 873392.25
# step = 12400: loss = 319263.40625
# step = 12600: loss = 23992.234375
# step = 12800: loss = 98391.609375
# step = 13000: loss = 8107.8115234375
# step = 13000: loss = 8107.8115234375
# step = 13000: Average Return = -265.1000061035156
# Avg of Steps/Episode: 16.13
# step = 13200: loss = 103586.6875
# step = 13400: loss = 8580.7763671875
# step = 13600: loss = 8344.984375
# step = 13800: loss = 33890.4921875
# step = 14000: loss = 45179.515625
# step = 14000: loss = 45179.515625
# step = 14000: Average Return = -1035.0
# Avg of Steps/Episode: 17.54
# step = 14200: loss = 40350.53515625
# step = 14400: loss = 20798.505859375
# step = 14600: loss = 7419.96337890625
# step = 14800: loss = 9773.681640625
# step = 15000: loss = 5812.5068359375
# step = 15000: loss = 5812.5068359375
# step = 15000: Average Return = -260.20001220703125
# Avg of Steps/Episode: 17.86
# step = 15200: loss = 2607.29541015625
# step = 15400: loss = 25120.138671875
# step = 15600: loss = 3408.981689453125
# step = 15800: loss = 4155.91943359375
# step = 16000: loss = 468.8653564453125
# step = 16000: loss = 468.8653564453125
# step = 16000: Average Return = -1125.5999755859375
# Avg of Steps/Episode: 16.95
# step = 16200: loss = 6309.4482421875
# step = 16400: loss = 5220.91259765625
# step = 16600: loss = 1801.358154296875
# step = 16800: loss = 5881.7880859375
# step = 17000: loss = 704.9793701171875
# step = 17000: loss = 704.9793701171875
# step = 17000: Average Return = -645.5999755859375
# Avg of Steps/Episode: 16.13
# step = 17200: loss = 697.0903930664062
# step = 17400: loss = 589.0380249023438
# step = 17600: loss = 3098.637939453125
# step = 17800: loss = 7460.833984375
# step = 18000: loss = 1455.521240234375
# step = 18000: loss = 1455.521240234375
# step = 18000: Average Return = -510.0
# Avg of Steps/Episode: 17.24
# step = 18200: loss = 2680.2197265625
# step = 18400: loss = 1360.6103515625
# step = 18600: loss = 1910.9312744140625
# step = 18800: loss = 644.175048828125
# step = 19000: loss = 874.529541015625
# step = 19000: loss = 874.529541015625
# step = 19000: Average Return = -195.1999969482422
# Avg of Steps/Episode: 17.86
# step = 19200: loss = 579.6351318359375
# step = 19400: loss = 2320.91650390625
# step = 19600: loss = 10380.88671875
# step = 19800: loss = 2389.5849609375
# step = 20000: loss = 1292.148681640625
# step = 20000: loss = 1292.148681640625
# step = 20000: Average Return = -440.1000061035156
# Avg of Steps/Episode: 18.18
# step = 20200: loss = 8526.1796875
# step = 20400: loss = 2223.123779296875
# step = 20600: loss = 1339.498291015625
# step = 20800: loss = 1825.548828125
# step = 21000: loss = 9776.291015625
# step = 21000: loss = 9776.291015625
# step = 21000: Average Return = 19.5
# Avg of Steps/Episode: 19.61
# step = 21200: loss = 254.3378448486328
# step = 21400: loss = 3780.5439453125
# step = 21600: loss = 147.912841796875
# step = 21800: loss = 1005.0479736328125
# step = 22000: loss = 1586.2105712890625
# step = 22000: loss = 1586.2105712890625
# step = 22000: Average Return = -730.0
# Avg of Steps/Episode: 19.61
# step = 22200: loss = 1181.89501953125
# step = 22400: loss = 159.62765502929688
# step = 22600: loss = 1417.701171875
# step = 22800: loss = 2610.906494140625
# step = 23000: loss = 1167.0765380859375
# step = 23000: loss = 1167.0765380859375
# step = 23000: Average Return = -230.10000610351562
# Avg of Steps/Episode: 17.86
# step = 23200: loss = 386.684326171875
# step = 23400: loss = 261.99957275390625
# step = 23600: loss = 35105.32421875
# step = 23800: loss = 351226752.0
# step = 24000: loss = 89981776.0
# step = 24000: loss = 89981776.0
# step = 24000: Average Return = -1635.300048828125
# Avg of Steps/Episode: 15.87
# step = 24200: loss = 11387943.0
# step = 24400: loss = 228222.84375
# step = 24600: loss = 3639516.5
# step = 24800: loss = 2499508.75
# step = 25000: loss = 14487.853515625
# step = 25000: loss = 14487.853515625
# step = 25000: Average Return = -2220.10009765625
# Avg of Steps/Episode: 15.62
# step = 25200: loss = 569175.75
# step = 25400: loss = 420791.0
# step = 25600: loss = 125943.4375
# step = 25800: loss = 560168.75
# step = 26000: loss = 318971.5
# step = 26000: loss = 318971.5
# step = 26000: Average Return = -1645.300048828125
# Avg of Steps/Episode: 17.86
# step = 26200: loss = 511960.125
# step = 26400: loss = 276834.0625
# step = 26600: loss = 141235.625
# step = 26800: loss = 18397.978515625
# step = 27000: loss = 288177.6875
# step = 27000: loss = 288177.6875
# step = 27000: Average Return = -2225.10009765625
# Avg of Steps/Episode: 20.00
# step = 27200: loss = 48981.2578125
# step = 27400: loss = 68921.4765625
# step = 27600: loss = 27734.74609375
# step = 27800: loss = 9092.33203125
# step = 28000: loss = 118370.0234375
# step = 28000: loss = 118370.0234375
# step = 28000: Average Return = -1015.0
# Avg of Steps/Episode: 20.83
# step = 28200: loss = 69612.203125
# step = 28400: loss = 9748.953125
# step = 28600: loss = 38730.1640625
# step = 28800: loss = 63583.9453125
# step = 29000: loss = 6935.6005859375
# step = 29000: loss = 6935.6005859375
# step = 29000: Average Return = -670.4000244140625
# Avg of Steps/Episode: 19.61
# step = 29200: loss = 33396.9921875
# step = 29400: loss = 51817.94921875
# step = 29600: loss = 40887.80078125
# step = 29800: loss = 25974.166015625
# step = 30000: loss = 46368.453125
# step = 30000: loss = 46368.453125
# step = 30000: Average Return = -515.0
# Avg of Steps/Episode: 18.18
# step = 30200: loss = 14772.19140625
# step = 30400: loss = 33477.578125
# step = 30600: loss = 3981.402099609375
# step = 30800: loss = 8197.509765625
# step = 31000: loss = 25436.94140625
# step = 31000: loss = 25436.94140625
# step = 31000: Average Return = -1020.0
# Avg of Steps/Episode: 17.24
# step = 31200: loss = 10408.4921875
# step = 31400: loss = 11234.078125
# step = 31600: loss = 27339.82421875
# step = 31800: loss = 16280.251953125
# step = 32000: loss = 10028.7607421875
# step = 32000: loss = 10028.7607421875
# step = 32000: Average Return = -415.20001220703125
# Avg of Steps/Episode: 17.24
# step = 32200: loss = 11683.1611328125
# step = 32400: loss = 1491.958984375
# step = 32600: loss = 4261.33154296875
# step = 32800: loss = 29177.123046875
# step = 33000: loss = 4086.33642578125
# step = 33000: loss = 4086.33642578125
# step = 33000: Average Return = -225.10000610351562
# Avg of Steps/Episode: 18.18
# step = 33200: loss = 971.0753173828125
# step = 33400: loss = 9518.9189453125
# step = 33600: loss = 6857.279296875
# step = 33800: loss = 2438002.5
# step = 34000: loss = 15591.52734375
# step = 34000: loss = 15591.52734375
# step = 34000: Average Return = -2510.0
# Avg of Steps/Episode: 16.67
# step = 34200: loss = 327.6000061035156
# step = 34400: loss = 14402.052734375
# step = 34600: loss = 3073.8330078125
# step = 34800: loss = 5374.22314453125
# step = 35000: loss = 4211.40771484375
# step = 35000: loss = 4211.40771484375
# step = 35000: Average Return = 54.5
# Avg of Steps/Episode: 17.54
# step = 35200: loss = 5097.8466796875
# step = 35400: loss = 5797.810546875
# step = 35600: loss = 581.6340942382812
# step = 35800: loss = 1513.3441162109375
# step = 36000: loss = 650.02392578125
# step = 36000: loss = 650.02392578125
# step = 36000: Average Return = 89.69999694824219
# Avg of Steps/Episode: 17.54
# step = 36200: loss = 1304.76220703125
# step = 36400: loss = 1348.147705078125
# step = 36600: loss = 1214.1400146484375
# step = 36800: loss = 3599.240234375
# step = 37000: loss = 3173.75146484375
# step = 37000: loss = 3173.75146484375
# step = 37000: Average Return = 19.899999618530273
# Avg of Steps/Episode: 15.38
# step = 37200: loss = 796.19384765625
# step = 37400: loss = 4459.23193359375
# step = 37600: loss = 7991.26904296875
# step = 37800: loss = 1750.0816650390625
# step = 38000: loss = 1502.380126953125
# step = 38000: loss = 1502.380126953125
# step = 38000: Average Return = 20.0
# Avg of Steps/Episode: 16.95
# step = 38200: loss = 1733.010498046875
# step = 38400: loss = 139597984.0
# step = 38600: loss = 8863309.0
# step = 38800: loss = 9409770.0
# step = 39000: loss = 8514255.0
# step = 39000: loss = 8514255.0
# step = 39000: Average Return = -2520.0
# Avg of Steps/Episode: 17.54
# step = 39200: loss = 1915605.375
# step = 39400: loss = 2419852.5
# step = 39600: loss = 816686.9375
# step = 39800: loss = 194158.125
# step = 40000: loss = 502861.90625
# step = 40000: loss = 502861.90625
# step = 40000: Average Return = -1930.0999755859375
# Avg of Steps/Episode: 18.87
# step = 40200: loss = 314990.1875
# step = 40400: loss = 20430.779296875
# step = 40600: loss = 115720.484375
# step = 40800: loss = 246760.25
# step = 41000: loss = 127210.890625
# step = 41000: loss = 127210.890625
# step = 41000: Average Return = -2515.0
# Avg of Steps/Episode: 20.41
# step = 41200: loss = 20115.62109375
# step = 41400: loss = 20662.369140625
# step = 41600: loss = 18437.7265625
# step = 41800: loss = 94026.625
# step = 42000: loss = 129029.421875
# step = 42000: loss = 129029.421875
# step = 42000: Average Return = -2505.0
# Avg of Steps/Episode: 18.18
# step = 42200: loss = 44730.15234375
# step = 42400: loss = 126289.671875
# step = 42600: loss = 30515.966796875
# step = 42800: loss = 18564.49609375
# step = 43000: loss = 8310.83203125
# step = 43000: loss = 8310.83203125
# step = 43000: Average Return = -2520.0
# Avg of Steps/Episode: 17.86
# step = 43200: loss = 18188.76171875
# step = 43400: loss = 7925.82080078125
# step = 43600: loss = 31850.67578125
# step = 43800: loss = 150523.359375
# step = 44000: loss = 1351.10791015625
# step = 44000: loss = 1351.10791015625
# step = 44000: Average Return = -515.0
# Avg of Steps/Episode: 16.95
# step = 44200: loss = 35190.90234375
# step = 44400: loss = 5751.912109375
# step = 44600: loss = 58677.984375
# step = 44800: loss = 5702.048828125
# step = 45000: loss = 1323.524169921875
# step = 45000: loss = 1323.524169921875
# step = 45000: Average Return = -225.0
# Avg of Steps/Episode: 16.67
# step = 45200: loss = 7531.4443359375
# step = 45400: loss = 1580.7978515625
# step = 45600: loss = 17557.837890625
# step = 45800: loss = 10153.63671875
# step = 46000: loss = 23872.265625
# step = 46000: loss = 23872.265625
# step = 46000: Average Return = 124.4000015258789
# Avg of Steps/Episode: 16.13
# step = 46200: loss = 3074.84765625
# step = 46400: loss = 5686.2646484375
# step = 46600: loss = 10031.4189453125
# step = 46800: loss = 3547.3115234375
# step = 47000: loss = 1795.0537109375
# step = 47000: loss = 1795.0537109375
# step = 47000: Average Return = 89.69999694824219
# Avg of Steps/Episode: 14.29
# step = 47200: loss = 4257.72265625
# step = 47400: loss = 290.0219421386719
# step = 47600: loss = 1050.0982666015625
# step = 47800: loss = 836.88916015625
# step = 48000: loss = 5450.380859375
# step = 48000: loss = 5450.380859375
# step = 48000: Average Return = -1430.199951171875
# Avg of Steps/Episode: 13.89
# step = 48200: loss = 22167378.0
# step = 48400: loss = 19968386.0
# step = 48600: loss = 17722980.0
# step = 48800: loss = 597417.75
# step = 49000: loss = 244293.21875
# step = 49000: loss = 244293.21875
# step = 49000: Average Return = -2240.0
# Avg of Steps/Episode: 16.95
# step = 49200: loss = 883639.25
# step = 49400: loss = 1145834.875
# step = 49600: loss = 214306.5625
# step = 49800: loss = 47560.71875
# step = 50000: loss = 196849.109375
# step = 50000: loss = 196849.109375
# step = 50000: Average Return = -745.2999877929688
# Avg of Steps/Episode: 18.52
# step = 50200: loss = 161924.625
# step = 50400: loss = 19079.28515625
# step = 50600: loss = 61834.265625
# step = 50800: loss = 111565.9921875
# step = 51000: loss = 105375.171875
# step = 51000: loss = 105375.171875
# step = 51000: Average Return = -510.20001220703125
# Avg of Steps/Episode: 16.39
# step = 51200: loss = 228565.125
# step = 51400: loss = 110309.8203125
# step = 51600: loss = 20167.78125
# step = 51800: loss = 21561.23828125
# step = 52000: loss = 2991.31591796875
# step = 52000: loss = 2991.31591796875
# step = 52000: Average Return = -2025.0
# Avg of Steps/Episode: 16.95
# step = 52200: loss = 7790.7607421875
# step = 52400: loss = 41692.49609375
# step = 52600: loss = 27280.953125
# step = 52800: loss = 28607.513671875
# step = 53000: loss = 3762.28466796875
# step = 53000: loss = 3762.28466796875
# step = 53000: Average Return = 54.70000076293945
# Avg of Steps/Episode: 18.18
# step = 53200: loss = 12714.6240234375
# step = 53400: loss = 11279.0126953125
# step = 53600: loss = 8061.41455078125
# step = 53800: loss = 3972.48486328125
# step = 54000: loss = 2357.9921875
# step = 54000: loss = 2357.9921875
# step = 54000: Average Return = -1550.0
# Avg of Steps/Episode: 16.67
# step = 54200: loss = 19691.2578125
# step = 54400: loss = 4208.501953125
# step = 54600: loss = 21234.724609375
# step = 54800: loss = 107385.09375
# step = 55000: loss = 3273.143310546875
# step = 55000: loss = 3273.143310546875
# step = 55000: Average Return = -1385.199951171875
# Avg of Steps/Episode: 15.87
# step = 55200: loss = 2340.507080078125
# step = 55400: loss = 6706.8310546875
# step = 55600: loss = 9427.482421875
# step = 55800: loss = 3653.640625
# step = 56000: loss = 1426.9051513671875
# step = 56000: loss = 1426.9051513671875
# step = 56000: Average Return = -215.10000610351562
# Avg of Steps/Episode: 15.38
# step = 56200: loss = 3074.618408203125
# step = 56400: loss = 1505.857666015625
# step = 56600: loss = 3904.754638671875
# step = 56800: loss = 1656.679931640625
# step = 57000: loss = 2264.3193359375
# step = 57000: loss = 2264.3193359375
# step = 57000: Average Return = -1260.0
# Avg of Steps/Episode: 14.49
# step = 57200: loss = 4139.9091796875
# step = 57400: loss = 3786.5615234375
# step = 57600: loss = 602.16357421875
# step = 57800: loss = 25179.1640625
# step = 58000: loss = 3412.92333984375
# step = 58000: loss = 3412.92333984375
# step = 58000: Average Return = -255.0
# Avg of Steps/Episode: 15.15
# step = 58200: loss = 536.0118408203125
# step = 58400: loss = 11154.5390625
# step = 58600: loss = 5477624.5
# step = 58800: loss = 205091.875
# step = 59000: loss = 18157312.0
# step = 59000: loss = 18157312.0
# step = 59000: Average Return = -2225.0
# Avg of Steps/Episode: 18.52
# step = 59200: loss = 23328.625
# step = 59400: loss = 43344.125
# step = 59600: loss = 291507.625
# step = 59800: loss = 233635.8125
# step = 60000: loss = 208596.8125
# step = 60000: loss = 208596.8125
# step = 60000: Average Return = -945.2000122070312
# Avg of Steps/Episode: 18.87
# step = 60200: loss = 36353.87109375
# step = 60400: loss = 97885.234375
# step = 60600: loss = 33358.53125
# step = 60800: loss = 5833.669921875
# step = 61000: loss = 18129.150390625
# step = 61000: loss = 18129.150390625
# step = 61000: Average Return = -15.0
# Avg of Steps/Episode: 16.39
# step = 61200: loss = 2110.7392578125
# step = 61400: loss = 10113.982421875
# step = 61600: loss = 71741.09375
# step = 61800: loss = 73506.2265625
# step = 62000: loss = 13142.4892578125
# step = 62000: loss = 13142.4892578125
# step = 62000: Average Return = -185.1999969482422
# Avg of Steps/Episode: 18.18
# step = 62200: loss = 2423.580322265625
# step = 62400: loss = 5124.98681640625
# step = 62600: loss = 6460.05419921875
# step = 62800: loss = 23941.923828125
# step = 63000: loss = 5628.18359375
# step = 63000: loss = 5628.18359375
# step = 63000: Average Return = -15.100000381469727
# Avg of Steps/Episode: 20.00
# step = 63200: loss = 8835.6474609375
# step = 63400: loss = 8546.912109375
# step = 63600: loss = 18471.5390625
# step = 63800: loss = 7805.0888671875
# step = 64000: loss = 11151.80859375
# step = 64000: loss = 11151.80859375
# step = 64000: Average Return = -800.0
# Avg of Steps/Episode: 19.23
# step = 64200: loss = 5832.7138671875
# step = 64400: loss = 4235.1416015625
# step = 64600: loss = 7560.859375
# step = 64800: loss = 11445.0703125
# step = 65000: loss = 21053.751953125
# step = 65000: loss = 21053.751953125
# step = 65000: Average Return = -2530.0
# Avg of Steps/Episode: 18.87
# step = 65200: loss = 238455.5625
# step = 65400: loss = 2387.43896484375
# step = 65600: loss = 32299.5546875
# step = 65800: loss = 2159.256591796875
# step = 66000: loss = 1089.41845703125
# step = 66000: loss = 1089.41845703125
# step = 66000: Average Return = 158.8000030517578
# Avg of Steps/Episode: 18.18
# step = 66200: loss = 3478.298828125
# step = 66400: loss = 734.1641235351562
# step = 66600: loss = 984.7705078125
# step = 66800: loss = 2128.92529296875
# step = 67000: loss = 1924.812255859375
# step = 67000: loss = 1924.812255859375
# step = 67000: Average Return = -1225.0
# Avg of Steps/Episode: 18.18
# step = 67200: loss = 15181.2802734375
# step = 67400: loss = 1724.860107421875
# step = 67600: loss = 481.0872497558594
# step = 67800: loss = 993876.5
# step = 68000: loss = 306375840.0
# step = 68000: loss = 306375840.0
# step = 68000: Average Return = -2495.0
# Avg of Steps/Episode: 19.61
# step = 68200: loss = 107118112.0
# step = 68400: loss = 8911571.0
# step = 68600: loss = 12201016.0
# step = 68800: loss = 26956648.0
# step = 69000: loss = 21048822.0
# step = 69000: loss = 21048822.0
# step = 69000: Average Return = -1955.199951171875
# Avg of Steps/Episode: 21.28
# step = 69200: loss = 8395697.0
# step = 69400: loss = 12411908.0
# step = 69600: loss = 177340.9375
# step = 69800: loss = 98567.234375
# step = 70000: loss = 490616.4375
# step = 70000: loss = 490616.4375
# step = 70000: Average Return = -1920.0
# Avg of Steps/Episode: 20.41
# step = 70200: loss = 1134334.125
# step = 70400: loss = 656764.125
# step = 70600: loss = 108681.1640625
# step = 70800: loss = 427967.03125
# step = 71000: loss = 2324632.0
# step = 71000: loss = 2324632.0
# step = 71000: Average Return = -990.0
# Avg of Steps/Episode: 18.18
# step = 71200: loss = 278725.875
# step = 71400: loss = 159121.859375
# step = 71600: loss = 14568.41796875
# step = 71800: loss = 196457.8125
# step = 72000: loss = 358158.8125
# step = 72000: loss = 358158.8125
# step = 72000: Average Return = -1405.0
# Avg of Steps/Episode: 18.18
# step = 72200: loss = 12531.7724609375
# step = 72400: loss = 15119.06640625
# step = 72600: loss = 17442.66796875
# step = 72800: loss = 31934.205078125
# step = 73000: loss = 444844.5
# step = 73000: loss = 444844.5
# step = 73000: Average Return = -1900.199951171875
# Avg of Steps/Episode: 17.24
# step = 73200: loss = 19169.439453125
# step = 73400: loss = 209976.25
# step = 73600: loss = 25211.14453125
# step = 73800: loss = 14668.884765625
# step = 74000: loss = 30195.3671875
# step = 74000: loss = 30195.3671875
# step = 74000: Average Return = 54.599998474121094
# Avg of Steps/Episode: 15.15
# step = 74200: loss = 359026.8125
# step = 74400: loss = 37061.484375
# step = 74600: loss = 16332.8505859375
# step = 74800: loss = 12539.66796875
# step = 75000: loss = 43802.03125
# step = 75000: loss = 43802.03125
# step = 75000: Average Return = -15.0
# Avg of Steps/Episode: 15.87
# step = 75200: loss = 120330.1328125
# step = 75400: loss = 7766.9921875
# step = 75600: loss = 17351.017578125
# step = 75800: loss = 11531.849609375
# step = 76000: loss = 4085.7880859375
# step = 76000: loss = 4085.7880859375
# step = 76000: Average Return = -1275.0
# Avg of Steps/Episode: 19.61
# step = 76200: loss = 8974.8056640625
# step = 76400: loss = 8001.0478515625
# step = 76600: loss = 6323.6318359375
# step = 76800: loss = 74068.78125
# step = 77000: loss = 967439.625
# step = 77000: loss = 967439.625
# step = 77000: Average Return = -445.20001220703125
# Avg of Steps/Episode: 20.83
# step = 77200: loss = 11276677.0
# step = 77400: loss = 78787096.0
# step = 77600: loss = 24045872.0
# step = 77800: loss = 15043846.0
# step = 78000: loss = 6148842.5
# step = 78000: loss = 6148842.5
# step = 78000: Average Return = -1940.300048828125
# Avg of Steps/Episode: 20.00
# step = 78200: loss = 12994148.0
# step = 78400: loss = 18180788.0
# step = 78600: loss = 1109794.0
# step = 78800: loss = 26810564.0
# step = 79000: loss = 900458.375
# step = 79000: loss = 900458.375
# step = 79000: Average Return = -1450.0
# Avg of Steps/Episode: 21.28
# step = 79200: loss = 1309546.75
# step = 79400: loss = 219052.890625
# step = 79600: loss = 31174.2265625
# step = 79800: loss = 1278373.25
# step = 80000: loss = 303419.875
# step = 80000: loss = 303419.875
# step = 80000: Average Return = -2250.10009765625
# Avg of Steps/Episode: 19.61
# step = 80200: loss = 363388.09375
# step = 80400: loss = 1944537.875
# step = 80600: loss = 786951.3125
# step = 80800: loss = 1072552.125
# step = 81000: loss = 246134.3125
# step = 81000: loss = 246134.3125
# step = 81000: Average Return = -430.29998779296875
# Avg of Steps/Episode: 18.52
# step = 81200: loss = 8347.638671875
# step = 81400: loss = 18656.392578125
# step = 81600: loss = 79259.765625
# step = 81800: loss = 23575.08203125
# step = 82000: loss = 26457.69921875
# step = 82000: loss = 26457.69921875
# step = 82000: Average Return = -225.1999969482422
# Avg of Steps/Episode: 21.28
# step = 82200: loss = 16302.3798828125
# step = 82400: loss = 136824.328125
# step = 82600: loss = 13625.568359375
# step = 82800: loss = 24927.8046875
# step = 83000: loss = 30848.16796875
# step = 83000: loss = 30848.16796875
# step = 83000: Average Return = -15.0
# Avg of Steps/Episode: 20.00
# step = 83200: loss = 19949.564453125
# step = 83400: loss = 25473.953125
# step = 83600: loss = 6298.29296875
# step = 83800: loss = 5825.330078125
# step = 84000: loss = 19364.3671875
# step = 84000: loss = 19364.3671875
# step = 84000: Average Return = 89.5999984741211
# Avg of Steps/Episode: 16.67
# step = 84200: loss = 7644.05078125
# step = 84400: loss = 34540.19140625
# step = 84600: loss = 83437.6015625
# step = 84800: loss = 1020711.8125
# step = 85000: loss = 632137.0
# step = 85000: loss = 632137.0
# step = 85000: Average Return = -475.29998779296875
# Avg of Steps/Episode: 17.86
# step = 85200: loss = 539252800.0
# step = 85400: loss = 66136104.0
# step = 85600: loss = 8018420.0
# step = 85800: loss = 35987480.0
# step = 86000: loss = 22133402.0
# step = 86000: loss = 22133402.0
# step = 86000: Average Return = -910.0999755859375
# Avg of Steps/Episode: 21.74
# step = 86200: loss = 30341570.0
# step = 86400: loss = 2806723.5
# step = 86600: loss = 752856.0
# step = 86800: loss = 138451.25
# step = 87000: loss = 1004167.0625
# step = 87000: loss = 1004167.0625
# step = 87000: Average Return = -1670.0999755859375
# Avg of Steps/Episode: 21.74
# step = 87200: loss = 2866203.75
# step = 87400: loss = 1968393.25
# step = 87600: loss = 1153706.625
# step = 87800: loss = 330432.375
# step = 88000: loss = 1462131.0
# step = 88000: loss = 1462131.0
# step = 88000: Average Return = -1160.5
# Avg of Steps/Episode: 19.61
# step = 88200: loss = 681398.125
# step = 88400: loss = 1750076.25
# step = 88600: loss = 1732878.75
# step = 88800: loss = 1580740.25
# step = 89000: loss = 256228.53125
# step = 89000: loss = 256228.53125
# step = 89000: Average Return = -2235.0
# Avg of Steps/Episode: 18.52
# step = 89200: loss = 819506.125
# step = 89400: loss = 205874.53125
# step = 89600: loss = 245636.421875
# step = 89800: loss = 1392176.25
# step = 90000: loss = 10861.0146484375
# step = 90000: loss = 10861.0146484375
# step = 90000: Average Return = -1475.0999755859375
# Avg of Steps/Episode: 19.23
# step = 90200: loss = 29330.6484375
# step = 90400: loss = 29940.751953125
# step = 90600: loss = 1788294.0
# step = 90800: loss = 109954.171875
# step = 91000: loss = 268106.53125
# step = 91000: loss = 268106.53125
# step = 91000: Average Return = -510.0
# Avg of Steps/Episode: 19.23
# step = 91200: loss = 203906.78125
# step = 91400: loss = 230183.28125
# step = 91600: loss = 18922.05859375
# step = 91800: loss = 28779.818359375
# step = 92000: loss = 13820.2099609375
# step = 92000: loss = 13820.2099609375
# step = 92000: Average Return = -1210.4000244140625
# Avg of Steps/Episode: 17.54
# step = 92200: loss = 37733.48046875
# step = 92400: loss = 74457.5546875
# step = 92600: loss = 16318.828125
# step = 92800: loss = 142805.765625
# step = 93000: loss = 2350808.75
# step = 93000: loss = 2350808.75
# step = 93000: Average Return = -1940.0
# Avg of Steps/Episode: 17.24
# step = 93200: loss = 10033274.0
# step = 93400: loss = 77300896.0
# step = 93600: loss = 4764371.5
# step = 93800: loss = 45332448.0
# step = 94000: loss = 98313.796875
# step = 94000: loss = 98313.796875
# step = 94000: Average Return = -2515.0
# Avg of Steps/Episode: 16.67
# step = 94200: loss = 12662777.0
# step = 94400: loss = 521330.625
# step = 94600: loss = 785793.75
# step = 94800: loss = 396365.1875
# step = 95000: loss = 284360.90625
# step = 95000: loss = 284360.90625
# step = 95000: Average Return = -1190.300048828125
# Avg of Steps/Episode: 17.24
# step = 95200: loss = 411141.125
# step = 95400: loss = 323970.5625
# step = 95600: loss = 261106.375
# step = 95800: loss = 173441.46875
# step = 96000: loss = 463486.78125
# step = 96000: loss = 463486.78125
# step = 96000: Average Return = -2225.10009765625
# Avg of Steps/Episode: 17.54
# step = 96200: loss = 1356247.75
# step = 96400: loss = 312159.0
# step = 96600: loss = 35038.9765625
# step = 96800: loss = 420020.0625
# step = 97000: loss = 204657.09375
# step = 97000: loss = 204657.09375
# step = 97000: Average Return = -230.1999969482422
# Avg of Steps/Episode: 17.54
# step = 97200: loss = 112310.8046875
# step = 97400: loss = 46709.96875
# step = 97600: loss = 79305.90625
# step = 97800: loss = 52349.2578125
# step = 98000: loss = 6150.29248046875
# step = 98000: loss = 6150.29248046875
# step = 98000: Average Return = -1510.0
# Avg of Steps/Episode: 16.95
# step = 98200: loss = 20181.462890625
# step = 98400: loss = 39791.70703125
# step = 98600: loss = 26272.6953125
# step = 98800: loss = 93326.8125
# step = 99000: loss = 23000.01953125
# step = 99000: loss = 23000.01953125
# step = 99000: Average Return = -390.3999938964844
# Avg of Steps/Episode: 15.15
# step = 99200: loss = 24427.08203125
# step = 99400: loss = 12454.08203125
# step = 99600: loss = 20784386.0
# step = 99800: loss = 5477026.0
# step = 100000: loss = 3260570.5
# step = 100000: loss = 3260570.5
# step = 100000: Average Return = -2245.0
# Avg of Steps/Episode: 17.24
# CPU times: user 59min 33s, sys: 36 s, total: 1h 9s
# Wall time: 1h 14min 24s

# %% [markdown]
# ## Visualization

# %%
from resources import plot_moving_avg
plot_moving_avg('return', returns)

# %%
plot_moving_avg('loss', loss_log)

# %%
from resources import plot_metric_per_iteration
plot_metric_per_iteration(num_iterations, log_interval, episodes_per_log_interval, 'Episodes per log interval/iterations')

# %%
plot_metric_per_iteration(num_iterations, eval_interval, avg_steps_per_episode_per_eval_interval, 'Average Steps per Episode')

# %%
plot_metric_per_iteration(num_iterations, eval_interval, my_metric_log, 'Cumulative Crashes')

# %%
from resources import create_policy_eval_video

# Gera video da politica do agente treinado até então
create_policy_eval_video(agent.policy, "trained-agent", eval_env, eval_py_env)
# Out:
# WARNING:root:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (700, 700) to (704, 704) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to None (risking incompatibility). You may also see a FFMPEG warning concerning speedloss due to data not being aligned.
#     <video width="640" height="480" controls>
#     <source src="data:video/mp4;base64,..." type="video/mp4">
#     Your browser does not support the video tag.
#     </video>

# %% [markdown]
# ### Keep Training
